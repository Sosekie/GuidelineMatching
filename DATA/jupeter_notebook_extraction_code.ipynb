# %%
# %%capture
# !pip install dkpro-cassis pdfplumber PyMuPDF stanza

# %%
from cassis import *
from pathlib import Path
from pprint import pprint
import pandas as pd

# %%
import re
import pdfplumber
import stanza

# Initialize Stanford NLP pipeline
stanza.download("de")  # Download German models
nlp = stanza.Pipeline("de", processors="tokenize")

def extract_pdf_text(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        return " ".join([page.extract_text() for page in pdf.pages if page.extract_text()])

def split_into_paragraphs(text):
    # Split text into paragraphs using double line breaks
    paragraphs = re.split(r"\n\s*\n", text)
    return [p.strip() for p in paragraphs if p.strip()]

def clean_paragraph(paragraph):
    # Step 1: Remove "Ja" and "Nein"
    cleaned_paragraph = re.sub(r"\bJa\b|\bNein\b", "", paragraph)

    # Step 2: Remove lettered numbering like "a)", "b)", "c)"
    cleaned_paragraph = re.sub(r"^\s*[a-zA-Z]\)\s*", "", cleaned_paragraph, flags=re.MULTILINE)

    # Step 3: Remove numeric numbering like "1.", "2.", etc.
    cleaned_paragraph = re.sub(r"^\s*\d+\.\s*", "", cleaned_paragraph, flags=re.MULTILINE)

    # Step 4: Handle bullet points (replace "" with a connector like "; ")
    cleaned_paragraph = re.sub(r"", "; ", cleaned_paragraph)

    # Step 5: Merge line breaks into spaces
    cleaned_paragraph = re.sub(r"\s*\n\s*", " ", cleaned_paragraph).strip()

    return cleaned_paragraph

def split_by_semicolon(text):
    # Split the paragraph or sentence by semicolons (;) and remove leading/trailing spaces
    sentences = [s.strip() for s in re.split(r"\s*;\s*", text) if s.strip()]
    return sentences

def segment_text_with_stanza(text, nlp_pipeline):
    doc = nlp_pipeline(text)
    sentences = [sentence.text for sentence in doc.sentences]
    return sentences

# Paths
pdf_path = "1_Harmonisiert_oeffentliche_submission_gesunde_ernaehrung (1).pdf"

# Step 1: Extract text from PDF
pdf_text = extract_pdf_text(pdf_path)

# Step 2: Split text into paragraphs
paragraphs = split_into_paragraphs(pdf_text)

# Step 3: Process each paragraph
for i, paragraph in enumerate(paragraphs[:5], start=1):  # Limit to the first 5 paragraphs
    print(f"\nProcessing paragraph {i}...")

    # Clean the paragraph
    cleaned_paragraph = clean_paragraph(paragraph)

    # Step 4: Split by semicolon
    semicolon_split_sentences = split_by_semicolon(cleaned_paragraph)
#########################################################################################################
    # Step 5: Segment each part using Stanza
    #USING PRETRAINED STANFORDAI 
    all_sentences = []
    for sentence in semicolon_split_sentences:
        sentences = segment_text_with_stanza(sentence, nlp)
        all_sentences.extend(sentences)
        
#####################################################################################
    #SAVE FLIE INTO CSV
    df = pd.DataFrame(all_sentences, columns=['text'])
    df.to_csv("1_Harmonisiert_pflichtenheft.csv", index=False, encoding="utf-8")
    ##############################################################################
    
    # Output results
    print(f"Total sentences in paragraph {i}: {len(all_sentences)}")
    for j, sentence in enumerate(all_sentences, start=1):
        print(f"Sentence {j}: {sentence}")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-12-04 17:25:54 INFO: Downloaded file to C:\Users\Hamza\stanza_resources\resources.json
# 2024-12-04 17:25:54 INFO: Downloading default packages for language: de (German) ...
# 2024-12-04 17:25:56 INFO: File exists: C:\Users\Hamza\stanza_resources\de\default.zip
# 2024-12-04 17:26:02 INFO: Finished downloading models and saved to C:\Users\Hamza\stanza_resources
# 2024-12-04 17:26:02 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-12-04 17:26:02 INFO: Downloaded file to C:\Users\Hamza\stanza_resources\resources.json
# 2024-12-04 17:26:02 WARNING: Language de package default expects mwt, which has been added
# 2024-12-04 17:26:02 INFO: Loading these models for language: de (German):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# =======================
#
# 2024-12-04 17:26:02 INFO: Using device: cpu
# 2024-12-04 17:26:02 INFO: Loading: tokenize
# 2024-12-04 17:26:02 INFO: Loading: mwt
# 2024-12-04 17:26:02 INFO: Done loading processors!
# Processing paragraph 1...
# Total sentences in paragraph 1: 231
# Sentence 1: Öffentliche Submission Gesunde Ernährung «Kalte Linie Biel» in den Kitas und Tagesschulen der Stadt Biel Vergebende Stelle Stadt Biel Direktion Bildung, Kultur und Sport Abteilung Schule & Sport Zentralstrasse 60 2501 Biel Verfahrensart Offenes Verfahren gemäss Art.
# Sentence 2: 4 Verordnung über das öffentliche Beschaffungswesen (ÖBV
# Sentence 3: BSG 731.21) Wichtig Die Implementierung des Reglements «Gesunde Ernährung an den Bieler Betreuungsstrukturen» hat seinen Ursprung in einer städtischen Volksinitiative.
# Sentence 4: Der politische Prozess hat gezeigt, dass sowohl eine stadteigene Produktion (interne Produktion) als auch eine Produktion durch einen privaten Anbieter (externe Produktion) in Frage kommt.
# Sentence 5: Deshalb wird dieses Geschäft «unter Vorbehalt» als «Offenes Verfahren» öffentlich ausgeschrieben:
# Sentence 6: Die eingereichten Offerten wer- den zwar wie üblich gemäss ÖBV bewertet.
# Sentence 7: Der Sieger dieser Bewertung wird allerdings anschliessend zusätzlich noch dem stadteigenen Projekt gegenübergestellt.
# Sentence 8: Der Entscheid zwischen dem Gewinner der Ausschreibung und dem stadteigenen Projekt untersteht wiederum einem politischen Prozess.
# Sentence 9: Die Entscheidungskriterien hier sind politischer Natur und allenfalls nicht deckungsgleich mit den Kriterien der Ausschreibung
# Sentence 10: ebenfalls kann es sein, dass die Politik nochmals eine komplett neue Richtung für dieses Geschäft vorgibt.
# Sentence 11: Alle diese politischen Entscheidungen sind dann auch nicht mit den Rechtsmitteln gemäss ÖBV an- fechtbar.
# Sentence 12: Mit der Eingabe der Offerte bestätigen Sie die Kenntnisnahme, dass die Jury, aus Gründen des oben erwähnten demo- kratischen Prozesses wie auch zur Sicherstellung der Fachkompetenz, zum Teil aus Personen besteht, die auch am stadteigenen Projekt mitarbeiten.
# Sentence 13: Sie wissen als Mitbewerber, dass diese Jury bestrebt ist, die beste Lösung für die Stadt zu eruieren und ihr deshalb auch die nötige Objektivität in diesem Auswahlverfahren attestiert wird.
# Sentence 14: Ausgangslage Kitas und Tagesschulen nehmen Kinder ab Geburt bis 16 Jahren auf
# Sentence 15: aus allen sozialen Schichten, mit unterschiedlichs- ter Herkunft, Kultur und Religion.
# Sentence 16: Gemäss Beschluss des Stadtrats am 12.10.2016 muss die Qualität der Ernährung an den Bieler Tagesschulen und Kitas neu entsprechend dem Reglement «Gesunde Ernährung» sichergestellt werden (Siehe Reglement im Anhang).
# Sentence 17: Diese Qualität soll über die Einführung der «Kalten Linie Biel» gewährleistet werden.
# Sentence 18: Mittels einer zentralen Produktion werden reglementkonform die Mittagsmahlzeiten wie auch zum Teil die Zwischenmahlzeiten produziert und an die Tagesschulen und Kitas ausgeliefert.
# Sentence 19: Für die Sicherung von Qualitätsstandards wurden die Vorgaben des Reglements für diese Aus- schreibung messbar konkretisiert
# Sentence 20: auch finden sich im Anhang die Labels, an die sich eine Produktion zu halten hat.
# Sentence 21: Diese Standards gelten auch für das stadteigene Projekt (Siehe Absatz 2).
# Sentence 22: Aktuell verfügt die Stadt Biel über 6 Kitas und 13 Tagesschulen, wobei an einer Tagesschule noch ein Mittagstisch einer Oberstufe angegliedert ist.
# Sentence 23: Mittelfristig ist mit einem Ausbau (steigende Schülerzahlen) des Angebots zu rechnen.
# Sentence 24: Eben- falls könnte die Ausweitung der «Kalten Linie Biel» auf andere Betreuungsstrukturen (z.B. Altersheime) zu einem höhe- ren Volumen an Mahlzeiten führen.
# Sentence 25: Mit dem Wechsel auf die «Kalte Linie Biel» werden diese 20 Standorte so eingerichtet, dass die Menüs mittels Steamer effizient und schonend regeneriert werden können.
# Sentence 26: Je nach Entscheid kann es sein, dass die 5 Standorte, die aktuell über eine eigene Produktionsküche verfügen, als Übergangslösung weiterhin für sich selbst kochen.
# Sentence 27: Deshalb muss in dieser Ausgangslage auch von zwei Mengengerüsten bei der Anzahl Mahlzeiten ausgegangen werden.
# Sentence 28: Die Einrichtung der Standorte erfolgt nach festgelegten Standards durch die Stadt Biel.
# Sentence 29: Der Anbieter hat somit nicht mit zusätzlichen Investitionen oder mit der Abgabe von Leihgeräten zu rechnen und muss diese somit auch nicht in den Verkaufspreis kalkulieren.
# Sentence 30: Als Beispiel soll die geplante Infrastruktur des Standorts «Tagesschule Madretsch» aufgezeigt werden (Siehe Anhang 18.3).
# Sentence 31: Sprache des Verfahrens Das Angebot kann in Französisch oder Deutsch eingereicht werden.
# Sentence 32: Besondere Anforderungen Eine Zusammenarbeit mit weiteren Partnern ist in der Offerte offen zu legen.
# Sentence 33: Sie verpflichten sich mit der Eingabe der Offerte, dass auch von diesen Partnern die von Ihnen bestätigten Kriterien eingehalten werden.
# Sentence 34: Referenzen Der Bewerber kann entsprechende Referenzen vorweisen.
# Sentence 35: 2/14 Eignungskriterien «Kalte Linie Biel» - Auftragsgegenstand und Auftragsumfang Da das Reglement in der Zielsetzung strikte ist, sind etliche Punkte, anstatt wie üblich als Zuschlagskriterien, hier als Eignungskriterien aufgeführt.
# Sentence 36: Alle Punkte in dieser Selbstdeklaration sind somit Voraussetzungen für die Erfüllung des Auftrags
# Sentence 37: sie müssen zwingend erfüllt werden.
# Sentence 38: 1. Qualität Als Eignungskriterien finden Sie hier bei der «Qualität» die Mindestanforderungen des Reglements
# Sentence 39: weitere qualitative Aspekte werden unter den Zuschlagskriterien bewertet.
# Sentence 40: Bei Nennungen von Prozentanteilen (Anzahl, Franken, Gewicht) beziehen sich diese auf ein Jahr.
# Sentence 41: Beachten Sie auch, dass zwischen «Bio» und «Bio Suisse» unterschieden wird.
# Sentence 42: Sie produzieren warm zu servierende Speisen zu 70% (gemessen über das Gewicht) mittels «Cook and chill».
# Sentence 43: Die anderen 30% verteilen sich auf Produktionsarten wie «Schockfrosten», «Sous-vide», «hot fill» oder Weiteres.
# Sentence 44: Sie verwenden Öle, Gewürze, Streusalze, Zucker, Backwaren, wie auch weitere Basisprodukte und Nahrungsmittel für die Zwischenmahlzeiten zu 50% (an Kosten gemessen) in der Qualität «Bio» und (bei Produkten aus der 3. Welt) mit dem Gütesiegel «Max Havelaar».
# Sentence 45: Sie verwenden Milch und Milchprodukte zu 90% (gemessen an den Kosten) aus Schweizer Produktion in der Qualität «Bio».
# Sentence 46: Sie produzieren Sättigungsbeilagen zu 80% (in 8 von 10 Mahlzeiten) in der Qualität «Bio» und verwenden (bei Produkten aus der 3 Welt) Produkte mit dem Gütesiegel «Max Havelaar».
# Sentence 47: Kartoffeln verwenden Sie ausschliesslich in der Qualität «Bio Suisse» aus der Region (35km von Biel).
# Sentence 48: Früchte verarbeiten und liefern Sie zu 80% (gemessen an den Kosten) in Qualität «Bio Suis- se» (Siehe Ausnahmen unter g).
# Sentence 49: Fruchtsäfte verarbeiten und liefern Sie zu 80% (gemessen an den Kosten) in der Qualität «Bio» Sie liefern und verarbeiten zu 80% Früchte (gemessen an den Kosten) aus der Region (35km von Biel).
# Sentence 50: Es werden keine Früchte aus dem Ausland verwendet (Siehe Ausnahmen unter g).
# Sentence 51: Ausnahmen: Bananen, Mandarinen, Clementinen, Orangen: Diese sollen zu 70% (Gemessen an den Kosten) aus fairem Handel (Label Max Havelaar oder vergleichbar) und wenn möglich aus biologischer Produktion stammen.
# Sentence 52: Sie verwenden zu 70% Gemüse (gemessen an den Kosten) in der Qualität «Bio Suisse».
# Sentence 53: Sie verwenden zu 70% Gemüse (gemessen an den Kosten) aus der Region (35km von Biel).
# Sentence 54: Es wird kein Gemüse aus dem Ausland verwendet.
# Sentence 55: Sie verwenden Salat ausschliesslich in der Qualität «Bio Suisse».
# Sentence 56: Sie verwenden zu 70% Salat (gemessen an den Kosten) aus der Region (35km von Biel).
# Sentence 57: Es wird kein Salat aus dem Ausland verwendet.
# Sentence 58: Sie verarbeiten in 70% (in 7 von 10 Mahlzeiten) Fleisch/Geflügel/Fisch:
# Sentence 59: Fleisch/Geflügel in der Qualität «IP» oder «Bio Suisse» aus der Region (35km von Biel)
# Sentence 60: Fisch im Standard «MSC»
# Sentence 61: Als Mittagessen bieten Sie ein Hauptgericht bestehend aus:
# Sentence 62: Eiweisskomponente mit passender Sauce
# Sentence 63: Stärkebeilage
# Sentence 64: Gemüse und/oder Salat (mind. 2x Salat pro Woche)
# Sentence 65: 2x pro Woche wird ein Dessert geliefert
# Sentence 66: Die Hauptgerichte gestalten Sie:
# Sentence 67: 3 Hauptmahlzeiten pro Woche vegetarisch
# Sentence 68: 1 Hauptmahlzeit pro Woche abwechselnd Fleisch oder Geflügel
# Sentence 69: 1 Hauptmahlzeit pro Woche Fisch
# Sentence 70: Verarbeitete Fleischwaren/Fleischzubereitungen wie Würste und Brätprodukte werden maximal 2x/Monat geplant
# Sentence 71: Für Kinder die vegetarisch oder kein Schweinefleisch essen wird jeden Tag eine Ei- weisskomponente auf vegetarischer Basis angeboten.
# Sentence 72: Für Kinder mit Allergien kochen
# Sentence 73: Sie spezielle Mahlzeiten 3/14 Ihre Menüs sind variantenreich in Bezug auf Abwechslung.
# Sentence 74: Es werden keine Kopien der Me- nüpläne gemacht: Die Planung soll «rollend auf weisses Papier» erfolgen und erlaubt den Standorten ein direktes Mitspracherecht.
# Sentence 75: Auf spezielle Wünsche (Projekttage, Feste) können Sie eingehen.
# Sentence 76: Sie achten auf fettarme Eiweisskomponenten.
# Sentence 77: Sie achten auf sparsamen Einsatz von Zucker und Salz.
# Sentence 78: Babybrei wird ebenfalls in Qualität «Bio Suisse» produziert (Lieferung Tiefgekühlt).
# Sentence 79: Bei der Produktion verzichten Sie auf schädigende Konservierungsarten
# Sentence 80: für die Konservierung arbeiten Sie vorwiegend mit Mehrweggebinden.
# Sentence 81: 2. Volumen Eine minimale Abnahmemenge wird nicht definiert.
# Sentence 82: In den letzten Jahren hat die Anzahl Mittagsmahlzeiten in den Tagesschu- len zugenommen (2-4% pro Jahr).
# Sentence 83: In der Regel bleibt die Anzahl Mahlzeiten während eines Semesters stabil.
# Sentence 84: Sie liefern die nötige Anzahl Menüs pro Tag.
# Sentence 85: Die aktuelle Anzahl Mahlzeiten am Mittag entnehmen Sie der Tabelle im Anhang (18.1 Variante A).
# Sentence 86: Ebenfalls finden Sie dort die unterschiedliche Anzahl Betriebswochen während einem Jahr.
# Sentence 87: Je nach Entscheid des Stadtrats kann es sein, dass die 5 Standorte, die aktuell über eine eigene Produkti- onsküche verfügen, als Übergangslösung weiterhin für sich selbst kochen (18.2 Variante B).
# Sentence 88: Des- halb muss in dieser Ausgangslage auch von zwei Mengengerüsten bei der Anzahl Mahlzeiten aus- gegangen werden.
# Sentence 89: Sie können innerhalb von einem Monat auf Mengenschwankungen +/- 10% insgesamt und bei den einzelnen Standorten eingehen.
# Sentence 90: 3. Bestellung Wöchentliche Bestellung der Mahlzeiten sieben Tage im Voraus.
# Sentence 91: Sie verfügen über ein Online-Bestellsystem.
# Sentence 92: Sie bieten Menü-Vorschläge an, können aber auch spezifische Wünsche abdecken.
# Sentence 93: Einsicht über Herkunft und Qualität «Label» der Lebensmittel.
# Sentence 94: Einsicht zu Nährwerten.
# Sentence 95: Detaillierte Angaben für Vegetarier und Allergiker.
# Sentence 96: Flexible Bestellung (Waldausflug, Geburtstage …) ist möglich.
# Sentence 97: Während der Bürozeiten leicht erreichbare Ansprechperson (Deutsch und Französisch).
# Sentence 98: 4. Lieferung Sie liefern an jeden Standort direkt, bis in die Kühlzellen.
# Sentence 99: Die Organisation der Lieferung und Portionierung der Speisen passt zur, im Kapitel 3.0 deklarierten Einrichtung der Standorte.
# Sentence 100: Die aktuellen Adressen der Standorte finden Sie im Anhang 18.1 und 18.2
# Sentence 101: Die Kühlkette muss gewährleistet sein
# Sentence 102: die Qualität der Nahrung darf sich durch den Transport nicht vermindern.
# Sentence 103: Die Lieferzeiten entsprechen den Bedürfnissen der Standorte.
# Sentence 104: Die Lagerkapazität in den Standorten ist aktuell auf eine zweimalige wöchentliche Lieferung ausgelegt.
# Sentence 105: Auf Änderungen muss eingegangen werden können.
# Sentence 106: Die Liefergebinde entsprechen den Bedürfnissen der Standorte und des Reglements.
# Sentence 107: 90% der Lieferung (gemessen in kg) erfolgt in Mehrweggebinde, aktuell ½-GN-Schalen.
# Sentence 108: 4/14 Die Lieferung erfolgt portioniert nach Anzahl Ausgabestellen an den Standorten.
# Sentence 109: Beispiel: Der Standort X bestellt 80 Essen für 4 Gruppen.
# Sentence 110: Die Speisen sind auf die Gruppen à 20 Menüs zu portionieren.
# Sentence 111: Deklaration der Herkunft und Qualität «Label» der Lebensmittel.
# Sentence 112: Detaillierte Angaben zu den Nährwerten der Lebensmittel.
# Sentence 113: Detaillierte Angaben für Vegetarier und Allergiker.
# Sentence 114: 5. Rechnungsstellung Monatliche und übersichtliche Rechnungsstellung pro Standort.
# Sentence 115: Jährliche Zusammenstellung der bezogenen Leistungen.
# Sentence 116: 6. Angaben zur Firma Rechtsform einfache Gesellschaft Kollektivgesellschaft Kommanditgesellschaft Genossenschaft AG Kommandit AG GmbH übrige (Verein, virtuelle Unternehmung, vertragliche Bindung, etc.) Kontaktadresse …………………………………………………………………………………….. .............……………………………………………………………………………
# Sentence 117: Gründungsjahr ....................................................................................................................
# Sentence 118: Berufsausweis der verantwortlichen Fachpersonen ....................................................................................................................
# Sentence 119: Anzahl beschäftigte Mitarbeiter/Innen Administration Männer: ............... Frauen: ............... AZUBI: ...............
# Sentence 120: Anzahl beschäftigte Mitarbeiter/Innen Produktion Männer: ............... Frauen: ............... AZUBI: ............... Legen Sie – je nach Rechtsform – einen Handelsregisterauszug, die Statuten oder anderweitigen Beglaubigungen bei.
# Sentence 121: Die Produktion der Mahlzeiten ist max.
# Sentence 122: 25km ab direkter Agglomeration Biel angesiedelt Direkte Agglomeration = Gemeinden, die direkt an Biel angrenzen 7.
# Sentence 123: Verpflichtungen Sie bezahlen für gleichwertige Arbeit von Mann und Frau dieselben Löhne.
# Sentence 124: Produziert Ihre Firma gemäss Lebensmittelverordnung?
# Sentence 125: Bitte legen Sie uns den aktuellsten Be- richt/Rapport betreffend Lebensmittelinspektion bei.
# Sentence 126: Sind gegen Ihre Firma Betreibungen hängig?
# Sentence 127: Adresse des zuständigen Betreibungsamts ……………………………………………………………… Haben Sie die MwSt, die Staats-, Gemeinde- und Bundessteuern bis zum letzten Fälligkeitstermin bezahlt?
# Sentence 128: Haben Sie die AHV-/ IV-/EO- Beiträge, ALV, SUVA, Krankenkasse, Vor- /Fürsorgeeinrichtungen, Kinderzulagen usw. bis zum letzten Fälligkeitstermin bezahlt?
# Sentence 129: Alle Ihre Kommunikationsmittel zu Ihren Kunden sind zweisprachig (D und F).
# Sentence 130: Ebenfalls verfügen Sie in der Kommunikation in Bezug auf diesen Auftrag über Mitarbeitende in beiden Sprachen.
# Sentence 131: 8. Versicherungen Die Unternehmung erklärt, durch eine Haftpflichtversicherung ausreichend geschützt zu sein.
# Sentence 132: Es sind dies für Personenschäden pro Person CHF ........................... pro Ereignis CHF ...........................
# Sentence 133: 5/14 Sachschaden pro Ereignis CHF ...........................
# Sentence 134: Versicherungsgesellschaft ...............................................
# Sentence 135: Police Nr. ....................
# Sentence 136: Zuschlagskriterien Für jedes der folgenden Kriterien werden Punkte von 1-5 verteilt, die mit entsprechender Gewichtung für die Gesamtwer- tung addiert werden.
# Sentence 137: Bewertung 4-5 Gut 2-3 Genügend 1 Mangelhaft 0 Ungenügend 1. Qualität (Gewichtung 20%) Anforderung Bewertung Gewichtung Ausgewogenheit und kindergerecht innerhalb der Menüs:
# Sentence 138: Die Produktion folgt einer Die Jury wird 5% aufgrund eines Ernährungsphilosophie auf Basis einer aktuellen wissenschaftlicher Grundlage.
# Sentence 139: Rankings die Geben Sie Ihre Philosophie an Punkte vergeben Geben Sie uns Ihre Erfahrung in Bezug auf die Produktion von kindergerechten Me- Die Jury wird 5% aufgrund eines nüs an.
# Sentence 140: Deklarieren Sie Ihren Produktionsprozess in Form eines Flow – Charts für 4 Rankings die verschiedene Produkte: Punkte vergeben
# Sentence 141: Glasierte Karotten
# Sentence 142: Rindsgulasch
# Sentence 143: Teigwaren
# Sentence 144: Baby – Brei tiefgekühlt.
# Sentence 145: Referenzen angeben Machen Sie uns einen Vorschlag, wie die vorgegebene Qualität des Reglements von Die Jury wird 5% aufgrund eines uns in Ihrer Produktion überprüft werden kann.
# Sentence 146: Das Reglement schreibt eine jährliche Rankings die Überprüfung vor.
# Sentence 147: Punkte vergeben Erstellen
# Sentence 148: Sie einen Menüplan für 4 Wochen (Mittagessen) und setzen Sie darin alle
# Sentence 149: Die Jury wird 5% aufgrund eines deklarierten Anforderungen um.
# Sentence 150: Bezeichnen Sie bei jeder Menükomponente die ein- Rankings die gekaufte Qualität in Bezug auf alle Vorgaben des Kapitels 7.1a-r Punkte vergeben 2. Bestellung/Lieferung (Gewichtung 10%) Anforderung Bewertung Gewichtung Stellen
# Sentence 151: Sie Ihr Online-Bestellsystem für die Mahlzeiten in einer kurzen Beschreibung Die Jury wird 5% aufgrund eines vor.
# Sentence 152: Rankings die Punkte verge- ben Logistik: Wie gedenken Sie zu liefern?
# Sentence 153: Dokumentieren Sie mit Fotos.
# Sentence 154: Nennen Sie Ihre Die Jury wird 5% aufgrund eines Standards in Bezug auf den Umweltschutz.
# Sentence 155: Rankings die Punkte verge- ben 3. Preis (Gewichtung 40%) Anforderung Bewertung Gewichtung Durchschnittlicher Preis für eine Mittagsmahlzeit inkl.
# Sentence 156: Logistik.
# Sentence 157: Beachten Sie, dass pro Der beste Preis 40% erhält 5 Punkte Woche 2x Dessert gefordert sind.
# Sentence 158: Pro 10 Rappen Weisen Sie dabei den Preis für die Logistik separat aus.
# Sentence 159: Mehrkosten, 2 Punkte Abzug Der durchschnittliche Preis soll sich auf ein Jahr beziehen und die genannten Qualitätsanforderungen berücksichtigen
# Sentence 160: somit auch auf die genannte Gewichtung Fleisch, Vegi usw.
# Sentence 161: Geben Sie uns Ihre Preise für beide Mengengerüste an (siehe Anzahl Mahlzeiten im Anhang 18.1. und 18.2
# Sentence 162: sollte es zu einem Auftrag kommen, kann die Menge je nach politischem Entscheid variieren).
# Sentence 163: Ihre Preisangaben verstehen sich in Schweizer Franken inkl. MwSt.
# Sentence 164: Über den definierten Preis pro Mittagessen hinaus können der Stadt Biel keine weiteren Kosten verrechnet werden.
# Sentence 165: Die Preise für die Zwischenmahlzeiten (zMorge ohne Brot, zNüni, zVieri) und Babybreis werden Gegenstand bei den Vertragsverhandlungen.
# Sentence 166: Die Stadt Biel hat ein Interesse daran, auch diese Produkte beim gleichen Produzenten zu beziehen, doch wird auch dieser Zusatzauftrag vom Preis abhängig sein.
# Sentence 167: 6/14 4. Unternehmen (Gewichtung 25%) Anforderung Bewertung Gewichtung Standort der Produktion 10% a. Biel a) 5P b.
# Sentence 168: Direkte Agglomeration b) 3P c.
# Sentence 169: Direkte Agglomeration plus 25km c) 2P Geben Sie uns Einblick in Ihre Firmenwerte und - leitbilder Die Jury wird 5% aufgrund eines Rankings die Punkte verge- ben Wie viel des aktuellen Küchenpersonal aus den Tagesschulen und Kitas können Sie in 1 Punkt pro 100 5% Stellenprozente.
# Sentence 170: Ihre Produktion integrieren?
# Sentence 171: Max. 5 Punkte Wie viel Personen aus Wiedereingliederungs-Institutionen können Sie in Ihre Produk- 1 Punkt pro 100 5% Stellenprozente.
# Sentence 172: tion integrieren?
# Sentence 173: Max. 5 Punkte 5. Ausführungsfrist (Gewichtung 5%) Anforderung Bewertung Gewichtung Geben Sie uns an, nach wieviel Monaten, nach Erhalt des Zuschlags des Auftrags, Die kürzeste 5% Dauer erhält 5 Sie die ersten Mahlzeiten liefern können.
# Sentence 174: Punkte.
# Sentence 175: Pro Monat- Mehrdauer 0.2 Punkte Abzug Dauer des Auftrags Frühestens in fünf Jahren ab 1.
# Sentence 176: Lieferung kann der Auftrag neu ausgeschrieben werden.
# Sentence 177: Bezugsquelle der Ausschreibungsunterlagen Stadt Biel Matthias Klotz Abteilung Schule & Sport Ausschreibung «Gesunde Ernährung» Zentralstrasse 60 2501 Biel Auskunftsstelle Stadt Biel E-Mail: matthias.klotz@biel-bienne.ch Abteilung Schule & Sport Tel: +41 79 641 35 6 Matthias Klotz, Projektleiter «Gesunde Ernährung» Zentralstrasse 60 2501 Biel Angebotseinreichung Einreichen des Angebots an folgende Adresse: Persönlich Stadt Biel Matthias Klotz Abteilung Schule & Sport Ausschreibung «Gesunde Ernährung» Zentralstrasse 60 2501 Biel 1.
# Sentence 178: Frist
# Sentence 179: Die gesetzliche Frist von 40 Tagen für die Anbietenden (gemäss ÖBV Art.
# Sentence 180: 15) ist mit folgendem Abgabetermin ge- währleistet: September 2018 Massgebend ist der Poststempel oder das Abgabedatum bei persönlicher Abgabe.
# Sentence 181: Bei der Eingabe mit der Post werden nur Posteingänge bis max.
# Sentence 182: 5 Kalendertage nach der Eingabefrist berücksichtigt.
# Sentence 183: Die Teilnehmer tragen die Verantwortung für das rechtzeitige Eintreffen.
# Sentence 184: 2. Form Die Bewerbung ist in schriftlicher Form einzureichen: als lückenloses Angebot inkl.
# Sentence 185: Eignungs- und Zuschlagskrite- rien, unterschrieben in zwei Exemplaren in einem verschlossenen Umschlag mit Angabe des Betreffs.
# Sentence 186: Eingaben mittels E-Mail oder Fax wie auch auf jeglicher Art von Datenträger werden nicht berücksichtigt.
# Sentence 187: 7/14 3. Vorprüfungskriterien
# Sentence 188: Die eingereichten Bewerbungen werden nach folgenden Kriterien geprüft
# Sentence 189: Fristgerechte Einreichung der Unterlagen
# Sentence 190: Vollständigkeit der eingereichten Unterlagen
# Sentence 191: Lesbarkeit, Sprache Ein Nichteinhalten dieser Kriterien führt zu einem Ausschluss vom Verfahren.
# Sentence 192: Öffnung der Angebote September 2018 um 10.00 Uhr Ort: Abteilung Schule & Sport Ausschreibung «Gesunde Ernährung» Zentralstrasse 60 2501 Biel Bekanntgabe des Zuschlags unter Vorbehalt Voraussichtlich bis 15.
# Sentence 193: November 2018.
# Sentence 194: Die Bewerber werden schriftlich informiert.
# Sentence 195: Nicht berücksichtigte Bewerber haben kein Anrecht auf Entschädigung für den angefallenen Aufwand.
# Sentence 196: Die Anbietenden haben auf Verlangen die Möglichkeit, nach erfolgtem Zuschlag, in das anonymisierte Offertöff- nungsprotokoll Einsicht nehmen zu können (Art. 23 Abs. 4 ÖBV).
# Sentence 197: Das Einsichtsrecht erlischt mit Ablauf der Be- schwerdefrist.
# Sentence 198: Rechtsmittelbelehrung Diese Ausschreibung kann innert zehn Tagen nach der ersten Publikation mittels Beschwerde beim Regierungs- statthalteramt Biel, Schloss, Hauptstrasse 6, 2560 Nidau, angefochten werden.
# Sentence 199: Die Beschwerde ist im Doppel einzu- reichen.
# Sentence 200: Sie muss einen Antrag, die Angabe von Tatsachen und Beweismitteln, eine Begründung sowie eine Unter- schrift enthalten
# Sentence 201: greifbare Beweismittel sind beizulegen.
# Sentence 202: Beilagen
# Sentence 203: 18.1 Öffnungszeiten Standorte, Adressen, Anzahl Mahlzeiten Variante A
# Sentence 204: 18.2 Öffnungszeiten Standorte, Adressen, Anzahl Mahlzeiten Variante B
# Sentence 205: 18.3 Beispiel Geplante Infrastruktur Aussenstandort
# Sentence 206: 18.4 Reglement
# Sentence 207: 18.5 Labels 8/14 Bestätigung/Ermächtigung Mit der Unterzeichnung dieser Bestätigung übernehmen die Anbietenden die Verantwortung dafür, dass sämtliche Bedingungen und Auflagen von der eigenen Unternehmung und allenfalls beigezogenen Subunternehmen eingehal- ten werden und bestätigen auch ihre Bereitschaft, die Erfüllung dieser Bedingungen und Auflagen jederzeit zu bele- gen.
# Sentence 208: Die Anbietenden nehmen zur Kenntnis, dass die Auftraggebenden bei Falschangaben oder Missachtung der obigen Grundsätze: den Zuschlag jederzeit widerrufen und den Vertrag aus wichtigen Gründen vorzeitig auflösen, die Bezahlung einer Konventionalstrafe in der Höhe von 5% des gesamten Auftragswertes verlangen und/oder den fehlbaren Anbietenden bis zu fünf Jahren von künftigen Beschaffungen ausschliessen können.
# Sentence 209: Ort und Datum Firmenstempel Unterschriften 9/14 Anhang 1.
# Sentence 210: Tabelle Standorte: Alle Standorte werden beliefert (Variante A) Anzahl Betriebswochen Anzahl Mahlzeiten (Mittag) Anzahl Mahlzeiten (Mittag) Anzahl Standort Adresse pro Jahr pro Betriebswoche an Spitzentagen Kinderbrei pro Kinder Personal Kinder Personal Betriebswoche KITA Beundenweg Beundenweg 64, 2503 Biel 48 85 33 17 6 10 KITA Bubenberg Bubenbergstrasse 47, 2502 Biel 50 303 132 64 28 20 Kita Mett Safnernweg 21, 2504 Biel 48 314 113 87 20 51 Kita Rochette Hintergasse 2, 2504 Biel 48 113 40 24 8 20 Kita Soleil Sonnenstrasse 30, 2504 Biel 48 68 24 15 5 10 Kita Zukunft Zukunftstrasse 21, 2503 Biel 48 210 156 55 33 10 TS Battenberg Heidensteinweg 21, 2504 Biel 39 214 42 50 9 Solothurnstrasse 22, 2504 Biel / Hintergasse 12, 2504 Biel TS Bözingen Aktuell existieren zwei Küchen an zwei Adressen 39 299 42 66 9 Bubenbergstrasse 15, 2502 Biel TS Bubenberg Es sind zwei Küchen an gleicher Adresse geplant 39 530 153 122 41 TS Champagne Champagneallee 1, 2502 Biel 39 167 26 46 9 TS Dufour Dufourstrasse 22, 2502 Biel 39 449 47 111 12 TS Linde Seilerweg 64, 2503 Biel 39 333 30 106 8 TS Madretsch Galeerweg 8, 2503 Biel 39 162 30 37 7 Heideweg 21, 2503 Biel TS Mühlefeld Es sind zwei Küchen an gleicher Adresse geplant 39 250 44 61 10 TS Plänke Plänkestrasse 9, 2502 Biel 39 209 41 61 10 Poststrasse 23, 2504 Biel TS Poste Es sind zwei Küchen an gleicher Adresse geplant 39 237 35 58 8 TS Sahligut Jägerweg 1, 2504 Biel 39 274 40 67 9 TS Walkermatte Dreiangelweg 12, 2502 Biel 39 243 29 69 7 TS Zukunft Zukunftstrasse 21, 2503 Biel 39 114 18 29 4 OSZ Mett Bözingen Gleiche Adresse wie TS Sahligut 39 47 4 47 4 Total 4621 1079 1192 247 121 Altersgruppe Gewicht durchschnittliche Mahlzeit in Gramm Kinder Kita 0-4 Jahre 165 Kinder Tagsschule 4-12 Jahre 325 Personal und OSZ 400 10/14 2.
# Sentence 211: Tabelle Standorte: Nur 15 Standorte werden beliefert (Variante B) Anzahl Betriebswochen Anzahl Mahlzeiten (Mittag) Anzahl Mahlzeiten (Mittag) Anzahl Standort Adresse pro Jahr pro Betriebswoche an Spitzentagen Kinderbrei pro Kinder Personal Kinder Personal Betriebswoche KITA Beundenweg Beundenweg 64, 2503 Biel 48 85 33 17 6 10 KITA Bubenberg Bubenbergstrasse 47, 2502 Biel Keine Lieferung Kita Mett Safnernweg 21, 2504 Biel Keine Lieferung Kita Rochette Hintergasse 2, 2504 Biel 48 113 40 24 8 20 Kita Soleil Sonnenstrasse 30, 2504 Biel 48 68 24 15 5 10 Kita Zukunft Zukunftstrasse 21, 2503 Biel Keine Lieferung TS Battenberg Heidensteinweg 21, 2504 Biel 39 214 42 50 9 Solothurnstrasse 22, 2504 Biel / Hintergasse 12, 2504 Biel TS Bözingen Aktuell existieren zwei Küchen an zwei Adressen 39 299 42 66 9 Bubenbergstrasse 15, 2502 Biel TS Bubenberg Es sind zwei Küchen an gleicher Adresse geplant 39 530 153 122 41 TS Champagne Champagneallee 1, 2502 Biel Keine Lieferung TS Dufour Dufourstrasse 22, 2502 Biel 39 449 47 111 12 TS Linde Seilerweg 64, 2503 Biel 39 333 30 106 8 TS Madretsch Galeerweg 8, 2503 Biel Keine Lieferung Heideweg 21, 2503 Biel TS Mühlefeld Es sind zwei Küchen an gleicher Adresse geplant 39 250 44 61 10 TS Plänke Plänkestrasse 9, 2502 Biel 39 209 41 61 10 Poststrasse 23, 2504 Biel TS Poste Es sind zwei Küchen an gleicher Adresse geplant 39 237 35 58 8 TS Sahligut Jägerweg 1, 2504 Biel 39 274 40 67 9 TS Walkermatte Dreiangelweg 12, 2502 Biel 39 243 29 69 7 TS Zukunft Zukunftstrasse 21, 2503 Biel 39 114 18 29 4 OSZ Mett Bözingen Gleiche Adresse wie TS Sahligut 39 47 4 47 4 Total 3465 622 903 150 40 Altersgruppe Gewicht durchschnittliche Mahlzeit in Gramm Kinder Kita 0-4 Jahre 165 Kinder Tagsschule 4-12 Jahre 325 Personal und OSZ 400 11/14 3.
# Sentence 212: Beispiel Geplante Infrastruktur Aussenstandort (Änderungen vorbehalten) Standort TS, Madretsch, Galeerweg 8, 2503 Biel Kombisteamer, bau, 10 x 1/1 Tiefkühler, bau untertisch Kühlschrank, bau, GN 1/1 Spülmaschine, ertisch Standort 3 n 7 n 0 n 3 nt 0 ei 0 Ei 1 ei 1 u Tagesschule 1 1 1 1 Madretsch s s m ose n chlu Artikel Bild Masse Trinkwasser kalt Trinkwasser war Kaltwasser 0°fH Kaltwasser Osm Ablauf Zu beachten Spannung KW Typ - Steckdose Direkter Netzans 03 B 600 x 56 Ablauf 3NAC 10.5 CEE16 H 1250 Fest- 400v Kombisteamer T 750 anschluss, 50HZ einbau siphoniert, 10 x 1/1 GN Rohr- belüfter 07 B 600 1NAC 0.017 T13 H 820-880 230v Tiefkühler T 550 50HZ einbau untertisch 10 B 600 1NAC 0.95 T13 H 2100 230v Kühlschrank T 750 50HZ einbau GN 1/1 13 B 600 x 56 Ablauf 3NAC 7.9 CEE16 H 810-845 siphoniert 400v Spülmaschine T 620 50HZ untertisch 12/14 4.
# Sentence 213: Reglement 13/14 14/14 5.
# Sentence 214: Warenbeschaffungsrichtlinien (Labels) Nachhaltig produzierte Gemüse und Früchte
# Sentence 215: Sie produzieren im mindestens gemäss dem Modell 1 von «Bio Suisse» und lassen sich im mindestens gemäss diesem Modell zertifizieren.
# Sentence 216: Sie verpflichten sich zur Verwendung von Bio- Knospe-Produkten
# Sentence 217: das Volumen entspricht dem Vorgaben der Eignungskriterien.
# Sentence 218: Die Lebensmittel werden bei zertifizierten Lieferanten eingekauft.
# Sentence 219: Fleisch aus integrierter Produktion
# Sentence 220: Die Küche verpflichtet sich zum Einsatz von Fleisch aus IP Suisse-Produktion
# Sentence 221: das Volumen entspricht dem Vorgaben der Eignungskriterien.
# Sentence 222: Sämtliches Fleisch und alle Fleischwaren stammen aus der Schweiz und werden durch zertifizierte Ver- tragslieferanten geliefert.
# Sentence 223: Der Einkauf erfolgt nur über zertifi- zierte Lieferanten.
# Sentence 224: Fisch und Fischprodukte
# Sentence 225: Die Küche bezieht ausschliesslich MSC und ASC zertifizierte Fische und Fischprodukte und lässt sich als lizenzierter Verar- beiter zertifizieren
# Sentence 226: das Volumen entspricht dem Vorgaben der Eignungskriterien.
# Sentence 227: Der Lieferant muss ebenfalls zertifiziert sein.
# Sentence 228: Die Vorlaufzeit für eine Zertifizierung dauert ca. 6 Monate.
# Sentence 229: Kolonialwaren und exotische Produkte aus fairem Handel
# Sentence 230: Die eingesetzten Bananen, Zucker, Reis, Orangensaft und weitere Kolonialwaren wie Teigwaren, Getreide und Getreide- produkte tragen die Auszeichnung von Max Havelaar für fairen Handel und für faire Arbeitsbedingungen im Produktionsland.
# Sentence 231: Insbesondere bei den Stärkebeilagen sind weitere Label «Bio» Weitere möglich, welche unter Absprache mit Schule&Sport eingesetzt Biolabel werden dürfen.

# %%
import re
from cassis import *
from pathlib import Path
import fitz  # PyMuPDF
import pdfplumber
import csv


# File Paths for the first and second set of files
typesystem_path_1 = Path("./annotations/4_Harmonisiert_ausschreibung_herstellung")
xmi_path_1 = "4_Harmonisiert_ausschreibung_herstellung.xmi"

typesystem_path_2 = Path("./annotations/2_Harmonisiert_pflichtenheft")
xmi_path_2 = "2_Harmonisiert_pflichtenheft.xmi"

typesystem_path_3 = Path("./annotations/1_Harmonisiert_oeffentliche_submission_gesunde_ernaehrung")
xmi_path_3 = "1_Harmonisiert_oeffentliche_submission_gesunde_ernaehrung.xmi"

# Function to clean paragraphs (removes Ja, Nein, numbering, bullet points, and extra spaces)
def clean_paragraph(paragraph):
    # Step 1: Remove "Ja" and "Nein"
    paragraph = re.sub(r"\bJa\b|\bNein\b", "", paragraph)

    # Step 2: Split on lettered numbering like "a)", "b)", "c)"
    sentences = re.split(r"^\s*[a-zA-Z]\)\s*", paragraph, flags=re.MULTILINE)

    # Step 3: Further split on numeric numbering like "1.", "2.", etc.
    sentences = [s for sentence in sentences for s in re.split(r"^\s*\d+\.\s*", sentence, flags=re.MULTILINE)]
    
    # Step 4: Further split on bullet points ""
    sentences = [s for sentence in sentences for s in re.split(r"", sentence)]

    # Step 5: Further split on hyphens surrounded by spaces " - "
    sentences = [s for sentence in sentences for s in re.split(r"\s+–\s+", sentence)]

    # Step 6: Split on semicolons ";" (optional)
    sentences = [s for sentence in sentences for s in re.split(r"\s*;\s*", sentence)]

    # Step 7: Remove line breaks and strip spaces from each sentence
    sentences = [re.sub(r"\s*\n\s*", " ", s).strip() for s in sentences if s.strip()]

    return sentences



# Step 1: Load TypeSystem and XMI File
def load_xmi(typesystem_path, xmi_path):
    with open(typesystem_path / "TypeSystem.xml", "rb") as f:
        typesystem = load_typesystem(f)

    with open(typesystem_path / xmi_path, "rb") as f:
        cas = load_cas_from_xmi(f, typesystem=typesystem)
    
    return cas


# Assuming 'named_entities' is already defined and contains the entities
def process_named_entitie(named_entitie):
    data = {
        "text": [],
        "criterion_id": [],
        "criterion_type": []
    }

    # Populate data dictionary from named entities

    for ne in named_entitie:
        data["criterion_id"].append(ne.identifier.split("#")[-1])  # Extract the criterion ID
        data["criterion_type"].append(ne.value)  # Extract the criterion type
        data["text"].append(ne.get_covered_text())
    return data
# Step 2: Extract Sentences from XMI
def extract_sentences_from_cas(cas,xml_type):
    sentences = cas.select(xml_type)
    return sentences

# Step 3: Process and Clean Sentences
def process_sentences(sentences , skip_count=0):
    sentence_annotations = []
    for i, sentence in enumerate(sentences[skip_count:], start=skip_count + 1):
        # Extract sentence text
        cleaned_text = sentence.get_covered_text()

        # Clean the paragraph (remove "Ja", "Nein", numbering, etc.)
        cleaned_text = clean_paragraph(cleaned_text)

        # Create the sentence annotation
        for split_sentence in cleaned_text:
            sentence_annotations.append({
                "begin": sentence.begin,
                "end": sentence.end,
                "type": "SENTENCE",  # Similar to NamedEntity
                "text": split_sentence.strip(),  # Cleaned text
                "identifier": f"sentence-{sentence.begin}-{sentence.end}"  # Unique identifier based on span
            })

    return sentence_annotations

# Step 4: Output the Results
def output_results(sentence_annotations):
    # Print the total number of cleaned sentences
    print(f"SENTENCE NUMBERS : {len(sentence_annotations)}")
    for i, sentence in enumerate(sentence_annotations[:240], start=1):
        print(f"Sentence {i}: {sentence['text']} ")

def save_sentences_to_csv(sentences, file_name):
    # Create a DataFrame from the sentence texts
    df = pd.DataFrame(sentences, columns=['text'])
    
    # Save the DataFrame to a CSV file
    df.to_csv(file_name, index=False, encoding="utf-8")   # Directly write the sentence text


# Function to save named entities (criterion_id, criterion_type, and text) to CSV
def save_named_entities_to_csv(named_entities, file_name):
    # Create a DataFrame from the named entity data
    df = pd.DataFrame(named_entities, columns=['criterion_id', 'criterion_type', 'text'])
    
    # Save the DataFrame to a CSV file
    df.to_csv(file_name, index=False, encoding="utf-8")

# Main function to load XMI, extract sentences, clean, and display results
def main():
    Sentence_xml_type="de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Sentence"
    Namedentity_xml_type="de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity"
    # Load XMI and extract sentences for both sets of files for pdfs
    cas_1 = load_xmi(typesystem_path_1, xmi_path_1)
    sentences_1 = extract_sentences_from_cas(cas_1,Sentence_xml_type)
    sentence_cleaned_1 = process_sentences(sentences_1, skip_count=20)

    cas_2 = load_xmi(typesystem_path_2, xmi_path_2)
    sentences_2 = extract_sentences_from_cas(cas_2,Sentence_xml_type)
    sentence_cleaned_2 = process_sentences(sentences_2, skip_count=20)

    # Load XMI and extract sentences for both sets of files annotations
    
    cas_ne_1 = load_xmi(typesystem_path_1, xmi_path_1)
    ne_1 = extract_sentences_from_cas(cas_ne_1,Namedentity_xml_type)
    ne_cleaned_1 = process_named_entitie(ne_1)
    
    cas_ne_2 = load_xmi(typesystem_path_2, xmi_path_2)
    ne_2 = extract_sentences_from_cas(cas_ne_2,Namedentity_xml_type)
    ne_cleaned_2 = process_named_entitie(ne_2)
    
    cas_ne_3 = load_xmi(typesystem_path_3, xmi_path_3)
    ne_3 = extract_sentences_from_cas(cas_ne_3,Namedentity_xml_type)
    ne_cleaned_3 = process_named_entitie(ne_3)
    
    
#############################################################################################################
    #SVAE FILES INTO CSV:
    save_sentences_to_csv(sentence_cleaned_1, "4_Harmonisiert_ausschreibung.csv")
    save_sentences_to_csv(sentence_cleaned_2, "2_Harmonisiert_pflichtenheft.csv")
    save_named_entities_to_csv(ne_cleaned_1, "named_entity_annotations_4_Harmonisiert_ausschreibung.csv")
    save_named_entities_to_csv(ne_cleaned_2, "named_entity_annotations_2_Harmonisiert_ausschreibung.csv")
    save_named_entities_to_csv(ne_cleaned_3, "named_entity_annotations_1_Harmonisiert_ausschreibung.csv")
############################################################################################################
    
############################################################################################################
    #OPTIONAL PRINT 
    print("\nResults for 4_Harmonisiert_ausschreibung_herstellung:")
    output_results(sentence_cleaned_1)

    # Output results for the second set of files
    print("\nResults for 2_Harmonisiert_pflichtenheft:")
    output_results(sentence_cleaned_2)
    print ("\nAnnotations for 4_Harmonisiert_pflichtenheft:")
    print(ne_cleaned_1)
    print ("\nAnnotations for 2_Harmonisiert_pflichtenheft:")
    print(ne_cleaned_2)
    print ("\nAnnotations for 1_Harmonisiert_pflichtenheft:")
    print(ne_cleaned_3)
############################################################################################################

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Results for 4_Harmonisiert_ausschreibung_herstellung:
# SENTENCE NUMBERS : 182
# Sentence 1: ANGABEN ZUM SUBMISSIONSVERFAHREN
# Sentence 2: 1 VERFAHREN Die Auftragsvergabe erfolgt im offenen Verfahren im Staatsvertragsbereich gemäss den Bestimmungen der Interkantonalen Vereinbarung über das öffentliche Beschaffungswesen (IVöB) und der Submissionsverord- nung des Kantons Zürich (SubmV).
# Sentence 3: 2 AUFTRAGGEBERIN Stadt Illnau-Effretikon Abteilung Bildung, Bereich Betreuung Stadthaus, Märtplatz 29, 8307 Effretikon
# Sentence 4: 3 ZUSTÄNDIGE PERSON Franzisca Keel Leiterin Bereich Betreuung Stadthaus, Märtplatz 29, 8307 Effretikon 052 354 23 83 / franzisca.keel@ilef.ch
# Sentence 5: GEGENSTAND DER AUSSCHREIBUNG
# Sentence 6: 1 AUSGANGSLAGE Der Auftrag zur Herstellung und Lieferung der Mittagsverpflegung für drei schulergänzende Betreuungseinrich- tungen der Volksschule und für die zwei städtischen Kindertagesstätten der Stadt Illnau-Effretikon wird neu vergeben.
# Sentence 7: Pro Standort und Tag werden 20 bis 80 Kinder und teilweise deren Betreuungspersonen verpflegt.
# Sentence 8: Während der Schulferien sind die drei schulergänzenden Betreuungsstätten geschlossen.
# Sentence 9: Alle Kinder erhalten eine ausgewogene, abwechslungsreiche, altersgemässe und warme Mahlzeit.
# Sentence 10: Das Verpflegungssystem für die Betreuungseinrichtungen beruht auf dem Konzept der Kaltanlieferung durch den Anbietenden und Regeneration vor Ort durch die Angestellten der Betreuungseinrichtungen.
# Sentence 11: Die angelieferte Verpflegung wird von einzelnen Betreuungseinrichtungen individuell mit Rohkost ergänzt.
# Sentence 12: Den Betreuungseinrichtungen stehen für die Verpflegung Verpflegungsbudgets zu.
# Sentence 13: Im Rahmen der hierfür gel- tenden städtischen Rahmenbedingungen entscheiden sie selbständig über ihr Verpflegungsbudget.
# Sentence 14: Dabei ste- hen ihnen zwei Kostenstellen zur Verfügung: Eine für die Kaltanlieferung, die Gegenstand der vorliegenden Aus- schreibung ist, und eine für sogenannte Ergänzungseinkäufe.
# Sentence 15: Die Ergänzungseinkäufe beinhalten primär ergän- zende Lebensmittel zur warmen Mittagsverpflegung wie beispielweise Gemüse für Rohkost, Salat und Menage [Ketchup, Senf]).
# Sentence 16: Dieses System ermöglicht es den Betreuungsstätten situativ, auch Komponenten der warmen Mittagsverpflegung über die Ergänzungseinkäufe zu beziehen.
# Sentence 17: 2 AUFTRAGSUMSCHREIBUNG Gegenstand der vorliegenden Ausschreibung ist die Herstellung und Lieferung der Mittagsverpflegung (Kaltan- lieferung) für fünf Betreuungseinrichtungen für drei Jahre (1.
# Sentence 18: Juni 2023 bis 31.
# Sentence 19: Mai 2026).
# Sentence 20: Für die Auftraggeberin besteht die Option auf eine Vertragsverlängerung von zweimal einem Jahr.
# Sentence 21: Die Ausschreibung umfasst Angebotsplanung, Produktion, Logistik, Kommunikation, Support, Schulung, Bera- tung, elektronische Bestellplattform und Verrechnung.
# Sentence 22: Die detaillierte Leistungsumschreibung ergibt sich aus den Ausführungen im Kapitel 17 des vorliegenden Doku- mentes sowie dem Leistungsbeschrieb (Beilage 3).
# Sentence 23: SUBMISSION HERSTELLUNG UND LIEFERUNG MITTAGESVERPFLEGUNG BETREUUNG 5 / 12
# Sentence 24: TEILNAHMEBEDINGUNGEN UND VORGABEN FÜR DIE ANBIETENDEN Global- oder Pauschalangebote sind nicht zulässig.
# Sentence 25: 1 SUBUNTERNEHMEN Der Vertrag wird mit dem Anbietenden abgeschlossen, der das gesamte ausgeschriebene Dienstleistungspa- ket abdeckt.
# Sentence 26: Eine Aufteilung in Lose ist nicht möglich.
# Sentence 27: Eine Zusammenarbeit des Anbietenden mit einem Sub- unternehmende oder Unterlieferanten ist möglich.
# Sentence 28: Sieht der Anbietende den Beizug von Subunternehmungen vor, hat er diese unter vollständiger Angabe der erforderlichen Daten im Rahmen der Offerte verbindlich anzugeben.
# Sentence 29: Subunternehmende müssen unter ande- rem die Grundsätze von Art. 11a und 11e bis 11g der Interkantonalen Vereinbarung über das Beschaffungswe- sen (IvöB) befolgen.
# Sentence 30: Sind die über die vorgesehenen Subunternehmenden gemachten Angaben unvollständig, kann die Offerte aus- geschlossen werden.
# Sentence 31: Erfüllen die genannten Subunternehmenden nach begründeter Einschätzung des Auf- tragsgebenden die Anforderungen oder Eignungskriterien nach eingeholter Stellungnahme des Anbietenden nicht, kann die Vergabestelle eine Alternative verlangen oder das Angebot wegen Nichteignung ausschliessen.
# Sentence 32: Sollte der Anbietende zum Zeitpunkt der Vertragsunterzeichnung oder des Ausführungsbeginnes aus von ihm unverschuldeten Gründen (z.B. wegen unvorhergesehener Verzögerung der Entscheidungsmechanismen, be- hördlicher Entscheide) gezwungen sein, andere Subunternehmer beizuziehen, als zwischen der Vergabestelle und Anbietenden vereinbart, ist dies der Vergabestelle sofort nach Bekanntwerden schriftlich mitzuteilen.
# Sentence 33: In diesem Fall muss die Vergabestelle erneut über die Zulassung entscheiden.
# Sentence 34: Die vollständige Verantwortung des Anbietenden wird durch das Beiziehen von Subunternehmenden nicht be- einträchtigt.
# Sentence 35: Verträge zwischen Anbietenden und Subunternehmenden schliesst der Anbietende in seinem Na- men und auf seine Rechnung ab.
# Sentence 36: BEZUGSSTELLE DER SUBMISSIONSUNTERLAGEN Die Submission wird am 01.Dezember 2022 auf www.simap.ch publiziert.
# Sentence 37: Die Unterlagen stehen dort zum Download bereit.
# Sentence 38: AUSKÜNFTE, FRAGEN Fragen zum Verfahren und zu den Ausschreibungsunterlagen sind in schriftlicher Form über www.simap.ch bis am 14.
# Sentence 39: Dezember 2022 zu erfassen.
# Sentence 40: Im Forumsbeitrag können unter dem Link «Eine Frage stellen» die ent- sprechenden Fragen gestellt bzw. erfasst werden.
# Sentence 41: Die schriftlichen Antworten aller Anbieter werden bis am 16.
# Sentence 42: Dezember 2022 anonymisiert auf www.simap.ch zur Verfügung gestellt.
# Sentence 43: Es werden keine telefonischen Auskünfte erteilt.
# Sentence 44: SPRACHE DER ANGEBOTE UND UNTERLAGEN Deutsch SUBMISSION HERSTELLUNG UND LIEFERUNG MITTAGESVERPFLEGUNG BETREUUNG 6 / 12
# Sentence 45: ORT UND ZEITPUNKT FÜR DIE EINREICHUNG DER UNTERLAGEN Das Angebot ist in Papierform, verschlossen und mit folgender Aufschrift einzureichen: Stadt Illnau-Effretikon Abteilung Bildung, Submission Mittagsverpflegung Betreuung Stadthaus, Märtplatz 29 8307 Effretikon Eingabetermin: Dienstag, 10.
# Sentence 46: Januar 2023, 10.00 Uhr Angebote per Telefon, Fax oder Mail sind nicht zulässig.
# Sentence 47: Änderungen und Streichungen im Text der Ausschrei- bung sind nicht zulässig.
# Sentence 48: Massgebend ist der Zeitpunkt des Eingangs am oben angegebenen Ort.
# Sentence 49: Der Poststempel ist weder massge- bend noch ausreichend.
# Sentence 50: DAUER DER VERBINDLICHKEIT DES ANGEBOTES Die Offerte muss ab Eingabedatum bis zum 1.
# Sentence 51: Juni 2023 gültig sein.
# Sentence 52: TEILNAHMEVORAUSSETZUNGEN Es werden nur Angebote bewertet, welche die zwingenden Anforderungen in formeller sowie in materieller Hinsicht gemäss Leistungsbeschreibung Kapitel 17, des vorliegenden Dokuments und des Dokuments «Leis- tungsbeschrieb», Beilage 3, erfüllen.
# Sentence 53: 1 FORMELLE PRÜFUNG Die Nichteinhaltung von vergabe- bzw. verfahrensrechtlicher Anforderungen kann zum Ausschluss vom Verfahren führen.
# Sentence 54: Insbesondere können Angebote ohne weitere Prüfung vom Verfahren ausgeschlossen werden,
# Sentence 55: welche nicht termingerecht eingereicht wurden
# Sentence 56: welche die verlangten Angaben und Unterlagen gemäss 17.9 nicht vollständig enthalten
# Sentence 57: bei welchen die vorliegende Vorlage geändert wurde
# Sentence 58: die nicht rechtsgültig unterzeichnet sind oder andere wesentliche Formerfordernisse verletzt haben
# Sentence 59: welche ein ungewöhnlich niedriges Angebot einreichen und den Nachweis nicht erbringen, dass die Teil- nahmebedingungen eingehalten werden und die Auftragsbedingungen erfüllt werden können.
# Sentence 60: 2 EIGNUNGSPRÜFUNG Angebote können ohne weitere Prüfung vom Verfahren ausgeschlossen werden, wenn die Eignungskriterien gemäss 10. nicht erfüllt sind.
# Sentence 61: SUBMISSION HERSTELLUNG UND LIEFERUNG MITTAGESVERPFLEGUNG BETREUUNG 7 / 12
# Sentence 62: EIGNUNGSKRITERIEN Es werden nur Angebote von Anbietenden zugelassen, welche die formellen Anforderungen erfüllen und fol- gende Eignungskriterien ausweisen:
# Sentence 63: Für den Auftrag ausreichende Leistungsfähigkeit in fachlicher, finanzieller, technischer, organisatorischer und personeller Hinsicht.
# Sentence 64: Nachweis: Vollständig ausgefülltes Firmenprofil (Beilage 1) samt erforderlicher Beilagen.
# Sentence 65: Erfahrung von mindestens zwei Jahren in der Ausführung von vergleichbaren Leistungen im Bereich Mit- tagsverpflegung von Kindern im Alter von ein bis zwölf Jahren.
# Sentence 66: Nachweis: Drei Referenzen, laufend oder Abschluss nicht länger als zwei Jahre zurückliegend (Beilage 2).
# Sentence 67: Allfällige Subunternehmungen haben für ihren Anteil am Auftrag analoge Nachweise zu erbringen.
# Sentence 68: ZUSCHLAGSKRITERIEN Gemäss Weisung Ausgaben und Kredite und Richtlinie Nachhaltige Beschaffung der Stadt Illnau-Effretikon gel- ten unterstehende Zuschlagskriterien.
# Sentence 69: Der Zuschlag erfolgt an denjenigen Anbietenden mit der höchsten Punktzahl.
# Sentence 70: In der Liste der Zuschlagkriterien sind die detaillierten Angaben für die Nachweise und Bewertungsgrundlagen der jeweiligen Unterkriterien auf- geführt.
# Sentence 71: Preis 50 %
# Sentence 72: 1.
# Sentence 73: Jahressumme für Mittagsverpflegung und Lieferung, inklusive MWST - Preise Mittagessen und Lieferung (Beilage 4)
# Sentence 74: Produktqualität und Angebot 25 %
# Sentence 75: 1 Altersgerechtes Angebot für Kinder im Alter von ein bis zwölf Jahren mit attrakti- ven Menüs - Nachweis: Konzept Menüplanung (maximal eine A4-Seite) - Beispiel Menüplan Sommer und Winter für je 4 Wochen - Bericht einer Ernährungsfachperson bezüglich Nährwert und Menüplanung (maximal eine A4-Seite) - Referenz (Beilage 2).
# Sentence 76: Die Referenzanfragen erfolgen durch die Abteilung Bildung.
# Sentence 77: 2 Zubereitung und Rezepturen - Nährstoffschonende Zubereitung und Verarbeitung - Vegetarische Komponenten
# Sentence 78: 3 Nachhaltigkeit - Regionale und saisonale Produkte - Minimierung von Foodwaste - Nachhaltige Verpackung / Gebinde
# Sentence 79: 4 Deklaration Komponenten auf Verpackung und im Webshop - Alle Speisen sind deklariert
# Sentence 80: .
# Sentence 81: - Zubereitungshinweise: Angaben zum fachgerechten Regenerieren der Speisen - Allergiker- Report im Webshop
# Sentence 82: 5 Gebinde-Einheiten - Aufzeigen von Einheiten SUBMISSION HERSTELLUNG UND LIEFERUNG MITTAGESVERPFLEGUNG BETREUUNG 8 / 12
# Sentence 83: Termineinhaltung 10 %
# Sentence 84: 1 Verlässliche Transport- und Logistikleistungen
# Sentence 85: Nachweis: Konzept Logistik mit Strategie (max. 2 A4-Seiten)
# Sentence 86: Referenz (Beilage 2)
# Sentence 87: 4 Umgang mit Notfällen
# Sentence 88: Nachweis: Konzept Notfall und Umsetzung bei Notfällen (maximal A4-Seite) Beispiele: Eine Betreuungsperson meldet nach dem Essen Magen-Darm-Beschwerden meh- rerer Kinder.
# Sentence 89: In einer grossen Betreuungseinrichtung wird am Morgen festgestellt, dass das Essen nicht fristgerecht geliefert wurde.
# Sentence 90: Lehrlingsausbildung 5 %
# Sentence 91: 1.
# Sentence 92: Anteil Lernende im Vergleich zur Gesamtzahl der Mitarbeitenden
# Sentence 93: Angaben im Dokument «Firmenprofil und Selbstdeklaration» (Beilage 1)
# Sentence 94: Benutzer 10 %
# Sentence 95: 1 Kundenfreundliches elektronisches Bestellwesen (Webshop)
# Sentence 96: 2 Dienstleistung vor Ort, Zusammenarbeit, Austausch und Feedbackmöglichkeit mit Auftraggeberin und Betreuungsstätten.
# Sentence 97: 3 Einführungs- und Schulungskonzept
# Sentence 98: AUSSCHLUSS VOM VERFAHREN Die Vergabestelle schliesst Anbietende aus einem laufenden Vergabeverfahren aus, wenn sie die Voraussetzun- gen gemäss § 4a Gesetz über den Beitritt zur revidierten Interkantonalen Vereinbarung über das öffentliche Beschaffungswesen (Beitrittsgesetz IVöB, LS 720.1) für die Teilnahme am Verfahren nicht oder nicht mehr er- füllen oder wenn sie den rechtskonformen Ablauf des Vergabeverfahrens durch ihr Verhalten beeinträchtigen.
# Sentence 99: OFFERTÖFFNUNG
# Sentence 100: 1 VERHANDLUNGEN Es werden keine Abgebotsrunden durchgeführt.
# Sentence 101: 2 OFFERTÖFFNUNG Die Offertöffnung ist nicht öffentlich.
# Sentence 102: Den Anbietenden wird nach der Zuschlagserteilung Einsicht in das Offer- töffnungsprotokoll gewährt (§ 27 Abs. 4 Submissionsverordnung [SVO, LS 720.11]).
# Sentence 103: SUBMISSION HERSTELLUNG UND LIEFERUNG MITTAGESVERPFLEGUNG BETREUUNG 9 / 12
# Sentence 104: VORBEHALTE Die Erteilung des Auftrags steht unter dem Vorbehalt der Bewilligung bzw.
# Sentence 105: Kreditfreigabe der zuständigen In- stanz.
# Sentence 106: TERMINE  UND ABLAUF DATUM WAS
# Sentence 107: 12.2022 Publikation auf simap.ch
# Sentence 108: 12.2022 Einreichung von Fragestellungen über www.simap.ch
# Sentence 109: 12.2022 Beantwortung Fragen und Publikation Antworten Di, 10.01.2023, 10.00 Uhr Eingabefrist für die Offerten
# Sentence 110: 01.2023 Offertöffnung
# Sentence 111: 01.- 13.01.2023 Prüfen der Offerten, Erstbewertung
# Sentence 112: 01.2022 Versand Termin Präsentation per Mail
# Sentence 113: /20.01 2023 Präsentation (Anbietende welche die Eignungskriterien erfüllen) Präsentation von Angebot, Unternehmung (20 Min.) und Fragen stel- len (10 Min.)
# Sentence 114: - 25.01.2023 Einholen der Referenzen
# Sentence 115: 02.2023 Stadtratsbeschluss über die Vergabe
# Sentence 116: 02.2023 Bekanntmachung des Vergabeentscheids April 2023 Vertragsabschluss, Kontakt mit Anbietenden, Schulung Mitarbeitende
# Sentence 117: 06.2023 Vertragsbeginn.
# Sentence 118: Erste Lieferung
# Sentence 119: WEITERE BESTIMMUNGEN
# Sentence 120: 1 RECHNUNGSSTELLUNG UND ZAHLUNGSFRIST Jede Betreuungseinrichtung erhält monatlich eine eigene elektronische Rechnung mit dem detaillierten Lie- ferverzeichnis des zurückliegenden Monats.
# Sentence 121: Die Rechnungen werden innerhalb einer Frist von 30 Tagen bezahlt.
# Sentence 122: 2 PREISE UND PREISANPASSUNGEN
# Sentence 123: Die Mehrwertsteuersätze betragen 2.5% für das gesamte Lebensmittelsortiment und 7.7% auf Trans- portkosten
# Sentence 124: .
# Sentence 125: – Im Preis werden die Kosten pro Mittagessen und die Transportkosten offeriert
# Sentence 126: .
# Sentence 127: – Der Beizug von Subunternehmungen ist mit Bewilligung der Anbietenden zulässig.
# Sentence 128: Für die beigezogenen Subunternehmenden gelten die gleichen Bedingungen wie für den Hauptanbietenden.
# Sentence 129: Der Auftragsge- bende rechnet ausschliesslich mit dem beauftragten Anbietenden ab, welche sowohl die volle Verantwor- tung für die Leistungen von Subunternehmenden trägt und mit diesen abrechnet.
# Sentence 130: Der vom Anbietenden offerierte Preis gilt für die ganze Vertragsdauer (inklusive allfälliger Verlängerung).
# Sentence 131: Ak- zeptiert werden Anpassungen aufgrund der Jahresteuerung gemäss Bundesamt für Statistik jeweils per 1.
# Sentence 132: - nuar.
# Sentence 133: SUBMISSION HERSTELLUNG UND LIEFERUNG MITTAGESVERPFLEGUNG BETREUUNG 10 / 12
# Sentence 134: 3 VERTRAGSGRUNDLAGEN (DAUER, KÜNDIGUNG, KONVENTIONALSTRAFE) Der Vertrag tritt per 1.
# Sentence 135: Juni 2023 in Kraft und wird für die Dauer von drei Jahren (1.
# Sentence 136: Juni 2023
# Sentence 137: 31.
# Sentence 138: Mai 2026) mit einseitiger Option zu Gunsten der Stadt Illnau-Effretikon auf eine Vertragsverlängerung um zwei weitere Jahre abgeschlossen.
# Sentence 139: Beide Parteien können den Vertrag ordentlich mit einer Kündigungsfrist von zwölf Monaten auf Ende der Lauf- frist kündigen.
# Sentence 140: Das Recht zur sofortigen Vertragsauflösung aus wichtigen Gründen (Unzumutbarkeit der Weiter- führung des Vertragsverhältnisses) steht beiden Parteien zu.
# Sentence 141: Der Anbietende verpflichtet sich ausdrücklich, im Falle der Auftragserteilung per 1.
# Sentence 142: Juni 2023 mit der Mahlzeiten- lieferung.
# Sentence 143: Für Verzögerungen, welche vom Anbietenden verursacht werden, wird eine Konventionalstrafe von Fr. 2‘500.- pro Tag vereinbart.
# Sentence 144: Diese dient dem Auftraggebenden, die Verpflegung in der Übergangszeit sicher zu stellen.
# Sentence 145: 4 ÄNDERUNG DER VERTRAGSGRUNDLAGEN Wesentliche Änderungen der Vertragsgrundlagen berechtigen beide Vertragsparteien zu Vertragsverhandlun- gen vor Ablauf der Dreijahresfrist.
# Sentence 146: Für den Fall, dass sich die der Ausschreibung zugrundeliegenden und beschriebenen Entwicklungsszenarien langfristig und wesentlich nicht so entwickeln sollten, wie in der Ausschreibung dargestellt, verpflichten sich die beiden Parteien, im Rahmen des vorliegenden Vertrags das Gespräch für einvernehmliche Vertragsanpassungen zu suchen und Lösungen zu entwickeln.
# Sentence 147: 5 MÄNGEL BEI DER VERTRAGSERFÜLLUNG, AUSSERORDENTLICHE KÜNDIGUNG Bei Mängeln in der Vertragserfüllung gilt folgendes Vorgehen:
# Sentence 148: Gespräch der beiden Vertragsparteien zur Problemanalyse und Vereinbarung von Lösungen.
# Sentence 149: Erfolgt keine Verbesserung der Situation: Zweimalige schriftliche Abmahnung durch die Auftraggeberin mit konkreten Vorgaben.
# Sentence 150: Wenn keine Erfüllung der Vorgaben erfolgt: Vertragsauflösung mit einer Frist von 3 Monaten
# Sentence 151: 6 VERGABE Die Vergabestelle behält sich vor, gestützt auf § 28 der kantonalen Submissionsverordnung, Anbietende vom Verfahren auszuschliessen, insbesondere bei Unvollständigkeit des Angebots oder nicht erfüllen der Eignungs- kriterien.
# Sentence 152: Die Submission und Vergabe erfolgt vorbehältlich des Vergabeentscheides durch den Stadtrat.
# Sentence 153: Die eingereichten Unterlagen können bis drei Wochen nach rechtskräftiger Vergabe vom Anbietenden zurück- verlangt werden, andernfalls werden sie vernichtet.
# Sentence 154: 7 RECHTSMITTELBELEHRUNG Gegen diese Ausschreibung kann innert 10 Tagen, von der Publikation an gerechnet, beim Verwaltungsgericht des Kantons Zürich, Postfach, 8090 Zürich, schriftlich Beschwerde eingereicht werden.
# Sentence 155: Die Beschwerdeschrift ist im Doppel einzureichen.
# Sentence 156: Sie muss einen Antrag und dessen Begründung enthalten.
# Sentence 157: Die angefochtene Aus- schreibung ist beizulegen.
# Sentence 158: Die angerufenen Beweismittel sind genau zu bezeichnen und, soweit möglich, bei- zulegen.
# Sentence 159: 8 GERICHTSSTAND Das Schweizer Recht ist sowohl auf das Verfahren als auch auf den abzuschliessenden Vertrag anwendbar.
# Sentence 160: Gerichtsstand ist Illnau-Effretikon.
# Sentence 161: SUBMISSION HERSTELLUNG UND LIEFERUNG MITTAGESVERPFLEGUNG BETREUUNG 11 / 12
# Sentence 162: LEISTUNGSBESCHREIBUNG
# Sentence 163: 1 AUFTRAG Die Stadt Illnau-Effretikon, Abteilung Bildung beauftragt die evaluierte Unternehmung für eine Vertragsperiode von drei Jahren (bzw. für zwei weitere Jahre) mit der Herstellung einer ausgewogenen, abwechslungsreichen Mittagsverpflegung für Kinder und Primarschüler/innen sowie deren Betreuungspersonen in fünf städtischen Betreuungseinrichtungen sowie mit deren Anlieferung und den damit verbundenen Serviceleistungen.
# Sentence 164: Der Dienstleistungsauftrag umfasst die Mittagsverpflegung für Kinder Im Alter von ein bis zwölf Jahren und Betreuungspersonen, jeweils von Montag bis Freitag.
# Sentence 165: 2 LIEFERZEITEN Geliefert wird Mittagsverpflegung für drei schulergänzende Betreuungsstätten während 38 Schulwochen (ca. 185 Liefertage im Jahr).
# Sentence 166: Während der Schulferien der Stadt Illnau-Effretikon sowie an Feier- und Brückentagen findet keine Lieferung statt.
# Sentence 167: Die Mittagsverpflegung für die zwei städtischen Kindertagesstätten wird während 48 Wochen pro Jahr gelie- fert (ca. 240 Liefertage im Jahr).
# Sentence 168: In der 2. und 3.
# Sentence 169: Sommerferienwoche sowie zwischen Weihnachten und Neu- jahr und an den Feier- und Brückentagen findet keine Lieferung statt.
# Sentence 170: 3 AUFTRAGSPOTENTIAL Portionen pro Woche Altersstufen Total 1-3 Jahre 4-7 Jahre 8-12 Jahre Erwachsene Kindertagesstätte Effretikon, 8307 Effretikon 250 64% 20% - 16% Kindertagesstätte Illnau, 8308 Illnau 170 70% 18% - 12% Betreuung Schlimperg, 8307 Effretikon 232 - 70% 20% 10% Betreuung Eselriet, 8307 Effretikon 213 - 86% 4% 10% Betreuung Illnau, 8308 Illnau 286 - 75%  20% 5% Total 1’151
# Sentence 171: 4 ANFORDERUNGEN AN ÖKOLOGIE UND NACHHALTIGKEIT Unter Einhaltung der vorliegenden Rahmenbedingungen unternimmt der Anbietende alles, um die Transporte möglichst gering zu halten.
# Sentence 172: Fahrten werden wo möglich zusammengelegt.
# Sentence 173: Umweltgerechte Fahrzeuge mit tie- fem Treibstoffverbrauch sind im Einsatz.
# Sentence 174: 5 REPORTING Bei der Auftragsdurchführung erstellt der Anbietende jährlich eine Bilanz des Gesamtwareneinsatzes (Einkaufs- werte über das Jahr gesehen).
# Sentence 175: Die Einhaltung der Vorgaben wird im Rahmen eines Controllings jährlich überprüft und anschliessend mit dem Anbietenden besprochen.
# Sentence 176: Allfällige Massnahmen und weitere Schritte werden gemeinsam definiert.
# Sentence 177: SUBMISSION HERSTELLUNG UND LIEFERUNG MITTAGESVERPFLEGUNG BETREUUNG 12 / 12
# Sentence 178: 6 ZUSAMMENARBEIT ANGEBOTSENTWICKLUNG Der Anbietende verfügt über ein Konzept, wie Anregungen zur Angebotsplanung aufgenommen oder wie Opti- mierungen von den Betreuungseinrichtungen abgeholt und
# Sentence 179: wo sinnvoll –umgesetzt werden können (Beilage 3, Ziff. 4).
# Sentence 180: 7 VERTRAULICHKEIT Der Anbietende erklärt sich damit einverstanden, alle Angaben, welche er im Rahmen dieser Submission Mit- tagsverpflegung Betreuung der Stadt Illnau-Effretikon erhält, vertraulich zu behandeln und nur für die Ange- botserstellung zu verwenden.
# Sentence 181: 8 BESTANDTEILE DER AUSSCHREIBUNG Beilage 1_Firmenprofil/Selbstdeklaration Beilage 2_Referenzen Beilage 3_Leistungsbeschrieb Beilage 4_Preise Mittagessen und Lieferung Mit der nachfolgenden Unterschrift bestätigt der Anbietende, dass - er die Ausschreibungsunterlagen anerkannt und die Richtigkeit aller Angaben im Rahmen des Angebots bestätigt und - er die vorstehend geforderten Leistungen ohne Ausnahme mit der geforderten Qualität erbringt.
# Sentence 182: Ort und Datum Firmenstempel und rechtsgültige Unterschriften
#
# Results for 2_Harmonisiert_pflichtenheft:
# SENTENCE NUMBERS : 321
# Sentence 1: Management Summary Der Kanton Aargau betreibt gestützt auf Art. 377 des Schweizerischen Strafgesetzbuches (StGB) vom 21.
# Sentence 2: Dezember 1937 (SR 311.0), Art. 11 des Konkordats der Kantone der Nordwest- und Inner- schweiz über den Vollzug von Strafen und Massnahmen vom 5.
# Sentence 3: Mai 2006 (SAR 253.020), § 16 des Einführungsgesetzes zur Schweizerischen Strafprozessordnung (EG StPO) vom 16.
# Sentence 4: März 2010 (SAR 251.200), § 7 der Verordnung über den Vollzug von Strafen und Massnahmen (Strafvoll- zugsverordnung, SMV) vom 9.
# Sentence 5: Juli 2003 (SAR 253.111) und der Verordnung über die Organisation der Justizvollzugsanstalt Lenzburg vom 21.
# Sentence 6: Januar 2004 (SAR 253.331) in Lenzburg eine Justizvoll- zugsanstalt (nachfolgend JVA), bestehend aus einer Strafanstalt für männliche Erwachsene und dem Zentralgefängnis, mit insgesamt 364 Plätzen.
# Sentence 7: Justizvollzugsanstalten haben die inhaftierten Personen zu den üblichen Zeiten mit Verpflegung zu versorgen, die angemessen zubereitet und ausgegeben wird und in Qualität und Menge den Anfor- derungen der Ernährungslehre und modernen Hygiene sowie dem Alter und Gesundheitszustand entspricht und soweit wie möglich religiösen und kulturellen Geboten Rechnung trägt (Empfehlungen des Europarats zum Freiheitsentzug, Europäische Strafvollzugsgrundsätze, Anhang zur Empfehlung R(87)3, Ziffer 25.1).
# Sentence 8: Die JVA verfügt über eine eigene Küche, in der die täglichen Mahlzeiten zubereitet werden.
# Sentence 9: Sie kann die hierfür erforderlichen Lebensmittel jedoch nur zum Teil aus der Produktion der anstaltseigenen Betriebe (Landwirtschaft, Gemüseanbau) beziehen.
# Sentence 10: Deshalb müssen Lebensmittel auch extern ein- gekauft werden.
# Sentence 11: Einleitung
# Sentence 12: 1.
# Sentence 13: Zweck des Dokuments Die Ausschreibungsunterlagen bilden in ihrer Gesamtheit die Grundlage für die Evaluation des Vertragspartners.
# Sentence 14: Das vorliegende Pflichtenheft stellt dabei das Grunddokument der Ausschreibungsunterlagen dar.
# Sentence 15: Es legt die Ausgangslage dar und gibt die Ziele und Anforderungen für die Erbringung der Leistungen des Anbieters vor.
# Sentence 16: Die nachfolgenden Kapitel beschreiben den Ausschreibungsgegenstand ausführlich.
# Sentence 17: Weiter enthält das vorliegende Pflichtenheft wichtige Informationen zum Ausschreibungsvorgehen und zur Form der Angebotseinreichung.
# Sentence 18: 2 Ziel der Ausschreibung Aktuell werden die benötigten Lebensmittel gestützt auf den im Rahmen eines Einladungsverfahrens abgeschlossenen Leistungsvertrag bezogen.
# Sentence 19: Der laufende Vertrag enden per 31.
# Sentence 20: Dezember 2022, weshalb die Leistung ab. 1.
# Sentence 21: Januar 2023 auszuschreiben ist.
# Sentence 22: Die einzelnen Bestellungen erreichen dabei keinen submissionsrechtlich relevanten Wert.
# Sentence 23: In der Gesamtheit überschreitet aber der jährli- che Rechnungsbetrag der Lieferungen von Fleischwaren den submissionsrechtlichen Grenzwert für eine öffentliche Ausschreibung (Anhang 2 der Interkantonalen Vereinbarung über das öffentliche Be- schaffungswesen [IVöB] vom 15.
# Sentence 24: November 2019 [SAR 150.960]).
# Sentence 25: Mit der vorliegenden Ausschreibung soll das wirtschaftlich günstigste und qualitativ beste und nach- haltigste Angebot für die Lieferungen von Fleischwaren ermittelt werden.
# Sentence 26: Mit dem Zuschlagsempfänger wird ein Rahmenvertrag über die Lieferung der Fleischwaren für das Jahr 2023 abgeschlossen.
# Sentence 27: Die JVA behält sich aber vor, insbesondere bei Aktionsangeboten, ein- zelne Produkte auf dem freien Markt bei anderen Anbietern zu beziehen. 5 von 18
# Sentence 28: Übersicht über die ausgeschriebenen Leistungen
# Sentence 29: 1.
# Sentence 30: Allgemeines Die im Preisangebotsformular (Beilage 2) bezeichneten und umschriebenen Fleischwaren sind, sofern nicht ausdrücklich etwas anderes vermerkt wird, in guter, handelsüblicher Qualität zu offerieren und in einwandfreiem Zustand zu liefern.
# Sentence 31: Die Bestellung erfolgt durch die JVA in der Regel einmal wöchentlich per Telefon oder E-Mail.
# Sentence 32: Die Anlieferung der bestellten Ware erfolgt in der Regel innert 3 Tagen, spätestens aber innert Wochenfrist.
# Sentence 33: Die Anlieferung ist möglich von Montag bis Freitag, jeweils von 07.30 bis 10.30 Uhr und von 13.30 bis 15.00 Uhr.
# Sentence 34: Die Lieferadressen sind: JVA Lenzburg, Strafanstalt, Ziegeleiweg 13, 5600 Lenzburg (Hauptlieferort) und JVA Lenzburg, Zentralgefängnis, Wilstrasse 51, 5600 Lenzburg.
# Sentence 35: Die Lieferungen sind von den Mitarbeitenden des Anbieters auszuladen und werden nach dem Abladen an der Rampe durch Mitarbeitende der JVA auf Vollständigkeit, Richtigkeit, und Qualität (inklusive Temperatur) hin kontrolliert.
# Sentence 36: Mangelhafte Waren hat der Anbieter umgehend zu ersetzen.
# Sentence 37: Falls der Anbieter dazu nicht in der Lage ist, ist die JVA berechtigt, Ersatz zu beschaffen und die dadurch entstandenen Mehrkosten dem Anbieter in Rechnung zu stellen.
# Sentence 38: 2.
# Sentence 39: Geschätztes Vertragsvolumen Die im Eingabeformular Preis (Beilage 2) aufgeführten Angaben zum Auftragsvolumen basieren auf realistischen Annahmen gestützt auf die Erfahrungen aus dem Vorjahr.
# Sentence 40: Die Vergabestelle bezie- hungsweise die JVA geht in Bezug auf das Vertragsvolumen keine Verpflichtung ein.
# Sentence 41: Anforderungen
# Sentence 42: 1 Allgemein Die massgeblichen Anforderungen sind in Form von Angaben zum Unternehmen, zu den verlangten Eignungskriterien samt Bestätigungen, Referenzen und Darstellung der Einhaltung der Schweizerischen Tierschutzstandards sowie der Prinzipien der ökologischen Nachhaltigkeit bei Produktion und Transport (Beilage 1) und im Eingabeformular Preis (Beilage 2) aufgeführt.
# Sentence 43: 2 Geheimhaltung Der Anbieter ist verpflichtet, Tatsachen (zum Beispiel Kenntnisse über Abläufe und Verhältnisse) und Daten, die weder offenkundig noch allgemein zugänglich sind, geheim zu halten und zur Wahrung des Amtsgeheimnisses beizutragen.
# Sentence 44: Dies unabhängig davon, ob solche Informationen unmittelbar aufgrund der Auftragserfüllung oder bloss bei Gelegenheit der Vertragserfüllung (beispielsweise nur schon aufgrund des Aufenthalts in den Räumlichkeiten des Kunden) erlangt werden.
# Sentence 45: Im Zweifelsfall sind alle Tatsachen und Daten vertraulich zu behandeln.
# Sentence 46: Die Geheimhaltungspflicht besteht schon vor Vertragsabschluss und bleibt auch nach Beendigung des Vertragsverhältnisses bestehen.
# Sentence 47: Sie ist beigezogenen Dritten schriftlich aufzuerlegen.
# Sentence 48: Im abzuschliessenden Vertrag mit dem künftigen Anbieter wird insbesondere auch klar geregelt, welche Daten wem bekannt gegeben werden dürfen.
# Sentence 49: 3 Vorgaben für die Selbstdeklaration Der Anbieter muss zu allen Anforderungen und zu allen Fragen in der Selbstdeklaration Stellung nehmen.
# Sentence 50: Nicht oder nicht klar beantwortete Fragen werden als "nicht erfüllt" bewertet.
# Sentence 51: Sollten zu 6 von 18 einzelnen Punkten keine Angaben gemacht werden können, so ist dies auf jeden Fall zu vermerken.
# Sentence 52: Mit der Unterzeichnung des Anforderungskatalogs wird die Richtigkeit der gemachten Angaben rechtsgültig bestätigt.
# Sentence 53: 4 Erläuterung zum Selbstdeklaration Die vom Anbieter ausgefüllte Selbstdeklaration ist ein zentrales Bewertungsinstrument der Offerte.
# Sentence 54: Es ist daher unabdingbar, dass die Selbstdeklaration korrekt ausgefüllt und mit der Offerte eingereicht wird.
# Sentence 55: Sie ist in drei Teile gegliedert:
# Sentence 56: Angaben zum Unternehmen
# Sentence 57: Eignungskriterien
# Sentence 58: Referenzen
# Sentence 59: 4.1 Eignungskriterien Diese Fragen sind in der Selbstdeklaration jeweils mit "EK" gekennzeichnet.
# Sentence 60: Sie sind mit ja oder nein zu beantworten.
# Sentence 61: Alle Eignungskriterien sind zu erfüllen.
# Sentence 62: Eine Beantwortung mit "nein" führt zum Ausschluss.
# Sentence 63: Ein Eignungskriterium ist erfüllt, wenn: a. es mit ja beantwortet und b. im Bemerkungsfeld auf den relevanten Abschnitt der Offerte des Anbieters referenziert wurde.
# Sentence 64: 4.2 Referenzen Es sind drei Referenzen aus den letzten drei Jahren anzugeben, in denen Lieferungen und Dienstleistungen im vergleichbaren Umfang, wie in dieser Ausschreibung gefordert, erbracht wurden.
# Sentence 65: Anbieter, die seit weniger als drei Jahren auf dem Markt auftreten, haben ihre organisatorische und fachliche Leistungsfähigkeit auf andere geeignete Weise darzulegen.
# Sentence 66: 5 Zuschlagskriterien Die Zuschlagskriterien sind: a.
# Sentence 67: Preis (Ausführungen zur Preisbewertung erfolgen unter Ziff. 7.4.3.3) b.
# Sentence 68: Qualität c.
# Sentence 69: Nachhaltigkeit d.
# Sentence 70: Referenzen Die Bewertung und die Gewichtung der Zuschlagskriterien sind unter Ziff. 7.4.3 aufgeführt.
# Sentence 71: Angebote
# Sentence 72: 1 Allgemein Die Angebote sollten mit dem beiliegenden Preisangebots-Formular (Beilage 2) eingereicht werden.
# Sentence 73: Anzugeben sind die Preise für jedes aufgeführte Lebensmittel und der Gesamtpreis.
# Sentence 74: Anzugeben ist der Bruttopreis in Schweizer Franken (CHF), inklusive Mehrwertsteuern (aktueller Satz) und sämtlicher Spesen (Verpackung, Gebinde, Porto, Transportkosten etc.) und abzüglich allfälliger Skonti und Rabatten.
# Sentence 75: Ein Kleinmengenzuschlag ist ausgeschlossen.
# Sentence 76: Mit der Abgabe seines Angebots hat der Anbieter seine Fähigkeit zur Erbringung der ausgeschriebenen Leistungen 7 von 18 nachzuweisen, sowie unter anderem die Einhaltung der gesetzlichen Anforderungen bezüglich Arbeitsschutz und Arbeitsbedingungen zu bestätigen.
# Sentence 77: In diesem Kapitel werden nachfolgend die allgemeinen Vorgaben der Ausschreibung wie beispielsweise die Verfahrensgrundsätze, der Terminplan der Submission oder die Anforderungen an die Offerte beschrieben.
# Sentence 78: Es sind keine Teilangebote zulässig.
# Sentence 79: 2 Ausschreibungsunterlagen Pflichtenheft (vorliegendes Dokument).
# Sentence 80: Dieses Dokument beschreibt den Ablauf der Ausschreibung und enthält alle notwendigen Anweisungen für die Einreichung von Offerten durch interessierte Anbieter.
# Sentence 81: Beilagen zum Pflichtenheft:
# Sentence 82: Beilage 01 Selbstdeklaration
# Sentence 83: Beilage 02 Eingabeformular Preis
# Sentence 84: Beilage 03 EK 01 Angebot- und Bestätigungsschreiben Die Ausschreibungsunterlagen können ausschliesslich über www.simap.ch bezogen werden.
# Sentence 85: 3 Rechtliche Grundlagen und Verfahrensgrundsätze
# Sentence 86: 3.1 Rechtliche Grundlagen Das Übereinkommen über das öffentliche Beschaffungswesen vom 15.
# Sentence 87: April 1994 (SR 0.632.231.422) findet auf alle Gesetze, Vorschriften, Verfahren und Praktiken betreffend die öffentlichen Beschaffungen durch Stellen, die, wie in Anhang I ausgeführt, diesem Übereinkommen unterliegen, Anwendung (Art.
# Sentence 88: I Ziff. 1 GPA).
# Sentence 89: Da der geschätzte Wert der Fleischwaren-Lieferungen den Schwellenwert gemäss Anhang 2 der IVöB erreicht, untersteht der vorliegende Dienstleistungsvertrag dem GPA.
# Sentence 90: Zudem kommt die Interkantonale Vereinbarung über das öffentliche Beschaffungswesen (IVöB) zur Anwendung, welche die Ausführungsbestimmungen für die Vorgaben öffentlicher Aufträge innerhalb und ausserhalb des Staatsvertragsbereichs enthält.
# Sentence 91: Da der geschätzte Wert des Auftrags den Schwellenwert gemäss Anhang 2 IVöB übersteigt, ist der Auftrag im öffentlichen Verfahren auszuschreiben (Art. 20 IVöB).
# Sentence 92: 3.2 Verfahrensgrundsätze Als Grundlage für die Offertstellung dienen ausschliesslich die vorliegenden Ausschreibungsunterlagen sowie schriftliche Aussagen der Vergabestelle (vgl. nachfolgend Ziff. 5.6 Ansprechstelle / Fragen).
# Sentence 93: Aussagen irgendwelcher anderer Stellen sind für die Offerte nicht relevant.
# Sentence 94: Preisangebotsrunden sind nicht zulässig, das heisst nach der Offerteingabe sind keine Preisanpassungen mehr möglich.
# Sentence 95: Das heisst gleichzeitig auch, dass die offerierten Preise in allfällige Verträge übernommen werden und während deren Laufzeit nicht mehr verhandelbar sind.
# Sentence 96: In Berücksichtigung der aktuell unsicheren Wirtschaftsentwicklungslage wird eine Preisanpassung von +/- 20% vom pro Lebensmittel offerierten Bruttopreis auf das gesamte Kalenderjahr gerechnet toleriert.
# Sentence 97: Die Abweichung ist zu begründen und zu belegen.
# Sentence 98: Hierfür sind die für die Offerte massgeblichen Grundlagen (bspw.
# Sentence 99: Liste des Wochen-/Monatspreises, Index des Marktpreises, Gebindekosten etc.) mit Angabe des Stichtags dem Angebot beizulegen.
# Sentence 100: Übersteigen die in 8 von 18 Rechnung gestellten Lieferungen diese Marge, ist der zuviel bezahlte Teil zurückzuzahlen bzw. auf der nächsten Rechnung gutzuschreiben.
# Sentence 101: Durch die Teilnahme an der Ausschreibung erwirbt der Anbieter keinerlei Rechte auf Ausführung oder Vergütung irgendwelcher Art.
# Sentence 102: Die Auftragsvergabe bleibt ausdrücklich der Vergabestelle vorbehalten.
# Sentence 103: Offerten sind in jedem Falle (auch bei Nichtzustandekommen eines Vertrags) kostenlos zu erstellen.
# Sentence 104: Die Vergabestelle behält sich das Recht vor, die Submission abzubrechen oder nur teilweise zu realisieren, falls wichtige Gründe dies erfordern (vgl.
# Sentence 105: Art. 43 IVöB).
# Sentence 106: 4 Terminplan Submissionsverfahren Verfahrensschritt Datum Publikation Ausschreibung im Amtsblatt und auf www.simap.ch  8.
# Sentence 107: November 2022 Ablauf Anfragefrist auf www.simap.ch 14.
# Sentence 108: November 202 Beantwortung Fragen auf www.simap.ch 21.
# Sentence 109: November 2022 Ablauf Eingabefrist 28.
# Sentence 110: November 2022 Offertöffnung 29.
# Sentence 111: November 2022 Entscheid zuständige Behörde  14.
# Sentence 112: Dezember 2022 Eröffnung der Zuschläge Frühestens ab 15.
# Sentence 113: Dezem- ber 2022 Beschwerdefrist 20 Tage ab Empfang Zu- schlagsverfügungen Vertragsabschluss Nach Rechtskraft
# Sentence 114: 5 Vertraulichkeit, Rückgabe und Copyright der Ausschreibungsunterlagen Durch die Annahme des Pflichtenhefts verpflichtet sich der Anbieter, alle Informationen und Tatsachen, die ihm im Zusammenhang mit diesem Projekt zur Kenntnis gelangen (sowohl während des Submissionsverfahrens als auch während einer allfälligen künftigen Zusammenarbeit mit dem Auftraggeber), vertraulich zu behandeln.
# Sentence 115: Ausgenommen sind Informationen, die offensichtlich öffentlich oder allgemein zugänglich sind.
# Sentence 116: Im Zweifelsfall sind Informationen und Daten als vertraulich zu behandeln.
# Sentence 117: Verstösse gegen die Geheimhaltungs- beziehungsweise gegen die Vertraulichkeitsverpflichtung führen zum Ausschluss vom Verfahren.
# Sentence 118: Die Vergabestelle behandelt die Angaben und Unterlagen der Anbieter vertraulich.
# Sentence 119: Vorbehalten bleiben die nach dem Zuschlag zu veröffentlichenden Mitteilungen und die den nicht berücksichtigten Anbietenden zwingend zu erteilenden Auskünfte (Art. 49 Abs. 3 IVöB).
# Sentence 120: Sämtliche Rechte (insbesondere Urheberrechte) an den Ausschreibungsunterlagen verbleiben jederzeit im Eigentum der Vergabestelle.
# Sentence 121: Die Ausschreibungsunterlagen dürfen ausschliesslich für die Erstellung einer eigenen Offerte verwendet, nicht an Dritte weitergegeben und müssen 9 von 18 zurückgeschickt beziehungsweise umgehend irreversibel gelöscht werden, falls von einer Offerte abgesehen wird.
# Sentence 122: Die Anbieter haben die Vorschriften der geltenden Datenschutzgesetzgebung zu beachten.
# Sentence 123: 6 Fragen Direkte, telefonische oder persönliche Kontakte zwischen einem Anbieter und der Vergabestelle oder einzelnen Personen der Vergabestelle sind nicht erlaubt.
# Sentence 124: Nach der Publikation der Submissionsunterlagen auf www.simap.ch  können die Anbieter auf www.simap.ch Fragen stellen.
# Sentence 125: Diese werden durch die Vergabestelle laufend via www.simap.ch beantwortet.
# Sentence 126: Letzter Termin, um Fragen zu stellen, ist der 14.
# Sentence 127: November 2022, 17:00 Uhr.
# Sentence 128: Die Vergabestelle beantwortet die Fragen bis spätestens 21.
# Sentence 129: November 2022, 17:00 Uhr.
# Sentence 130: Alle Fragen werden auf www.simap.ch protokolliert und beantwortet.
# Sentence 131: Die Fragen sind so zu formulieren, dass sie keine Aufschlüsse über den Fragesteller zulassen.
# Sentence 132: Sollte ein Anbieter nicht in den Besitz der Antworten kommen, hat er sich bei der Vergabestelle selber um eine entsprechende Zustellung zu kümmern.
# Sentence 133: Die Vergabestelle wird nur über www.simap.ch an die ihr bekannt gegebenen Kontaktadressen der Anbieter entsprechende Informationen versenden.
# Sentence 134: Nach dem angegebenen Zeitpunkt werden keine weiteren Fragen der Anbieter mehr beantwortet.
# Sentence 135: 7 Empfangsbestätigung Der Empfang aller wichtigen Dokumente (per Post oder E-Mail) im Rahmen der Offert- und Evaluationsphase muss bei Erhalt umgehend von der Empfängerseite (Vergabestelle oder Anbieter) per E-Mail rückbestätigt werden.
# Sentence 136: Der Versand von E-Mails erfolgt auf Gefahr der Anbieter.
# Sentence 137: Letztere haben ihre Sicherheitsmassnahmen im Bereich E-Mail-Verkehr (Firewalls, Virensoftware, Spam-Abwehr, etc.)
# Sentence 138: während des Ausschreibungsverfahrens so zu konfigurieren, dass eine Zustellung von elektronischen Daten und Informationen möglich ist.
# Sentence 139: 8 Pflichten des Anbieters
# Sentence 140: 8.1 Vollständigkeit, Informations- und Aufklärungspflicht Das Angebot muss sämtliche Anforderungen des vorliegenden Pflichtenhefts und seiner Beilagen berücksichtigen (Vollständigkeit).
# Sentence 141: Stellt der Anbieter in den Ausschreibungsunterlagen Lücken, Widersprüche oder Unstimmigkeiten fest oder erscheinen ihm einzelne Punkte als nicht zweifelsfrei, so hat er sich durch Rückfragen via www.simap.ch  Klarheit zu verschaffen (Informationspflicht).
# Sentence 142: Der Anbieter ist verpflichtet, Ausführungen in den Ausschreibungsunterlagen, die er für unzutreffend, änderungsbedürftig oder fehlerhaft hält, unmittelbar, präzis und knapp zu kommentieren.
# Sentence 143: Ebenso ist an der entsprechenden Position ausdrücklich und unmissverständlich zu vermerken, wenn Anforderungen nicht eingehalten werden können oder begründete Bedenken bezüglich Machbarkeit oder Wirtschaftlichkeit einzelner Anforderungen bestehen (Aufklärungspflicht).
# Sentence 144: Nachträgliche Einwendungen und Nachforderungen, die auf ungenügende Informationen oder Aufklärung zurückzuführen sind, werden nicht anerkannt. 10 von 18
# Sentence 145: 8.2 Arbeitsschutzbestimmungen, Gesamtarbeitsvertrag Der Anbieter verpflichten sich, die Standards gemäss Kernabkommen der ILO (International Labour Organization), die geltenden Arbeitsschutzbestimmungen sowie die Bedingungen der Gesamtarbeitsverträge, der Normalarbeitsverträge oder bei deren Fehlen die branchenüblichen Vorschriften einzuhalten, die an den Orten gelten, wo die Arbeiten ausgeführt werden.
# Sentence 146: Er erklärt sich bereit, Nachweise auf Aufforderung hin innert Frist beizubringen.
# Sentence 147: 8.3 Transparenz der Angebote Die Anbietenden verpflichten sich zur Transparenz bei der Angebotserstellung und gewähren der Vergabestelle auf Verlangen Einblick in die entsprechenden Unterlagen.
# Sentence 148: 9 Aufbau und Inhalt der Offerte
# Sentence 149: 9.1 Generell Soweit nachfolgend nichts anderes angegeben ist, ergeben sich die Anforderungen, welche der Anbieter unter diesen Titeln darzulegen hat, aus den anderen Kapiteln des Pflichtenhefts sowie den referenzierten Beilagen.
# Sentence 150: Der Anbieter hat die vorgesehenen Dokumente und Formulare gemäss den vorliegenden Ausschreibungsunterlagen unverändert zu verwenden.
# Sentence 151: Bei Verweisen auf eigene Beilagen sind genaue Angaben bezüglich dem referenzierten Dokument, Seite und Abschnitt zu machen.
# Sentence 152: 9.2 Gliederung des Angebots Das Angebot ist in Kapitel zu gliedern und in einem Ordner mit Register abzuliefern.
# Sentence 153: Jedes Kapitel entspricht einem Registerblatt.
# Sentence 154: Vor dem Kapitel 1 ist ein Inhaltsverzeichnis einzufügen, welches alle Seiten des Angebots umfasst.
# Sentence 155: Folgende Gliederung des Angebots ist verbindlich:
# Sentence 156: Kapitel 1 Management Summary (vgl. nachfolgend Ziff. 5.9.3.1)
# Sentence 157: Kapitel 2 Selbstdeklaration (vgl. nachfolgend Ziff. 5.9.3.2)
# Sentence 158: Kapitel 3 Preisangebot (vgl. nachfolgend Ziff. 5.9.3.3)
# Sentence 159: Kapitel 4 Verlangte Nachweise aus Selbstdeklaration (vgl. nachfolgend Ziff. 5.9.3.4)
# Sentence 160: Kapitel 5 Bemerkungen des Anbieters (vgl. nachfolgend Ziff. 5.9.3.5)
# Sentence 161: Kapitel 6 Weitere Beilagen (vgl. nachfolgend Ziff. 5.9.3.6)
# Sentence 162: 9.3 Informationen zu den einzelnen Kapiteln
# Sentence 163: 9.3.1 Kapitel 1: Management Summary Die wichtigsten Punkte der offerierten Leistungen sind auf maximal einer bis zwei Seiten zusammenzufassen.
# Sentence 164: 9.3.2 Kapitel 2: Selbstdeklaration In diesem Kapitel ist die vollständig ausgefüllte und unterzeichnete Selbstdeklaration (Beilage 01) beizubringen.
# Sentence 165: Die Selbstdeklaration ist das zentrale Bewertungsinstrument der Offerte.
# Sentence 166: Es ist daher unabdingbar, dass die Selbstdeklaration korrekt ausgefüllt und mit der Offerte eingereicht wird.
# Sentence 167: Hier stellt sich der Anbieter im Sinne eines Unternehmensportraits mittels den vollständig beantworteten Fragen in der Beilage 01 "Informationen zum Unternehmen" sowie den Vorgaben 11 von 18 gemäss EK-03 vor.
# Sentence 168: Zudem gibt der Anbieter vollständige und wahrheitsgemäss Erklärungen zu den Eignungskriterien ab.
# Sentence 169: Des Weiteren sind drei Referenzen anzugeben, in denen Lieferungen und Dienstleistungen im vergleichbaren Umfang wie in dieser Ausschreibung gefordert, in den letzten drei Jahren erbracht worden sind (vgl.
# Sentence 170: EK-04).
# Sentence 171: 9.3.3 Kapitel 3: Preisangebot Dieses Kapitel besteht aus dem vollständig ausgefüllten und unterzeichneten Eingabeformular Preis (Beilage 02).
# Sentence 172: Das Formular weist den jeweiligen Einzelpreis pro Fleischware (Gewicht pro Einheit) und den Gesamtpreis aus.
# Sentence 173: Wie in den Vertragseckpunkten (siehe Kapitel 8) aufgeführt, werden vom Anbieter keine weiteren Kosten (Verpackung, Porto, Wegpauschalen etc.) verrechnet.
# Sentence 174: Ebenso sind Kleinmengenzuschläge ausgeschlossen.
# Sentence 175: Sämtliche offerierten Preise sind in Schweizer Franken (CHF) und als Nettopreise, das heisst inklusive allfälliger Rabatte und Skonti anzugeben beziehungsweise zu offerieren.
# Sentence 176: Der Gesamtpreis ist inklusive gesetzlicher Mehrwertsteuer anzugeben.
# Sentence 177: 9.3.4 Kapitel 4: Verlangte Nachweise aus Selbstdeklaration In diesem Kapitel sind sämtliche verlangten Nachweise gemäss der Selbstdeklaration beizubringen.
# Sentence 178: 9.3.5 Kapitel 5: Bemerkungen des Anbieters Dieses Kapitel steht dem Anbieter für weitere Ausführungen oder Kommentare zu seinem Angebot zur Verfügung.
# Sentence 179: Der Inhalt dieses Kapitels fliesst jedoch nicht in die Bewertung ein, es dient lediglich dazu, allfällige Unklarheiten zu erläutern oder weitere Ausführungen zu machen.
# Sentence 180: 9.3.6 Kapitel 6: Weitere Beilagen Dieses Kapitel steht dem Anbieter für weitere Beilagen wie zum Beispiel weitere Zertifikate betreffend Nachhaltigkeit, Beschreibungen, Erfahrungsberichte oder Prospekte zur Verfügung.
# Sentence 181: 10 Hinweis zum Gebrauch der zur Verfügung gestellten Dokumente Mit den vorliegenden Ausschreibungsunterlagen erhält der Anbieter eine Selbstdeklaration mit Anforderungskatalog als ein mit Blattschutz versehenes Word/Excel-Dokument zur Erfassung der verlangten Angaben.
# Sentence 182: Die Struktur des Dokuments darf nicht verändert werden.
# Sentence 183: Jegliche Mutation der Struktur, zum Beispiel Kopieren des Anforderungskataloges in ein anderes Blatt, kann einen späteren Import in das Analysetool unmöglich machen.
# Sentence 184: Weiter sind nur die Antwortfelder (Zahl, vorgegebene Auswahlliste, Freitext usw.) sowie die Bemerkungsfelder auszufüllen.
# Sentence 185: Dabei ist zu beachten, dass nur die Verwendung einer beschränkten Anzahl Zeichen möglich ist.
# Sentence 186: Die Antwort kann daher auch so gestaltet werden, dass genau auf die jeweilige Stelle in der Offerte (Seite, Kapitel) referenziert wird.
# Sentence 187: 11 Offertabgabe (Form, Termin, Adresse) Mit der Unterzeichnung des Angebots bestätigt der Anbieter ausdrücklich, dass die Angaben korrekt und vollständig sind.
# Sentence 188: Die Vergabestelle prüft die Angaben des Anbieters und verlangt bei Bedarf weitere Nachweise.
# Sentence 189: Die vollständige Offerte ist in einem verschlossenen Couvert/Paket mit Angabe des Absenders bis zum 12 von 18
# Sentence 190: November 2022, 14:00 Uhr (Eintreffen bei Vergabestelle massgebend, nicht der Poststempel!)
# Sentence 191: an folgende Adresse einzureichen: Vertraulich Justizvollzugsanstalt Lenzburg Ziegeleiweg 13 5600 Lenzburg Der Vermerk Offerte Submission “Lebensmittellieferungen für die JVA Lenzburg“
# Sentence 192: Nicht öffnen!
# Sentence 193: ist deutlich sichtbar anzubringen.
# Sentence 194: Die Offerte kann persönlich, per Kurier oder per Post eingereicht werden.
# Sentence 195: Bei Zusendung per Post oder Kurier ist ebenfalls der Anbieter für das rechtzeitige Eintreffen der Offerte verantwortlich.
# Sentence 196: Anbietende, deren Offerte zu spät eingetroffen, nicht vollständig ausgefüllt oder nicht handschriftlich unterzeichnet worden ist, werden vom Verfahren ausgeschlossen.
# Sentence 197: Nach der Einreichung darf das Angebot nicht mehr geändert werden.
# Sentence 198: 12 Sprache Die Offerte und alle ihre Beilagen (insbesondere auch Belege und Nachweise) sind in deutscher Sprache einzureichen.
# Sentence 199: Fremdsprachige Bescheinigungen amtlicher Stellen sind in beglaubigter deutscher Übersetzung vorzulegen.
# Sentence 200: Beilagen von Lieferanten, Materialien und Zertifikaten dürfen in englischer Sprache abgefasst sein.
# Sentence 201: 13 Nachweis der Leistungsfähigkeit Die Vergabestelle kann von den Anbietenden zukünftig jederzeit den Nachweis ihrer finanziellen, wirtschaftlichen, personellen und fachlichen Leistungsfähigkeit einfordern.
# Sentence 202: Ebenso einen Betreibungsregisterauszug.
# Sentence 203: Zusätzlich sind die Fragen in der Beilage 01 (Information zum Unternehmen) vollständig zu beantworten.
# Sentence 204: 14 Gültigkeit der Offerte Die Offerte muss eine Gültigkeit von sechs Monaten ab Schlusstermin für den Eingang der Angebote aufweisen.
# Sentence 205: Die Gültigkeitsdauer verlängert sich um die Dauer eines allfälligen Beschwerdeverfahrens.
# Sentence 206: 15 Publikation / Rechtsmittel Die Publikation der Ausschreibung erfolgt auf der Plattform www.simap.ch.
# Sentence 207: Für den Fristenlauf von Beschwerden ist einzig die Publikation auf www.simap.ch und im Amtsblatt des Kantons Aargau massgebend.
# Sentence 208: Die Rechtsmittelbelehrung lautet wie folgt:
# Sentence 209: Gegen die Ausschreibung kann innert einer nicht erstreckbaren Frist von 20 Tagen seit Publikation beim Verwaltungsgericht des Kanton Aargau, Laurenzenvorstadt 11, 5001 Aarau, Beschwerde erhoben werden.
# Sentence 210: Es gelten keine Gerichtsferien.
# Sentence 211: Die Beschwerde ist schriftlich einzureichen und muss einen Antrag sowie eine Begründung enthalten.
# Sentence 212: Das heisst, es ist
# Sentence 213: anzugeben, wie das Verwaltungsgericht entscheiden soll, und
# Sentence 214: darzulegen, aus welchen Gründen diese andere Entscheidung verlangt wird. 13 von 18
# Sentence 215: Auf eine Beschwerde, welche den Anforderungen gemäss den Ziffern 1. und 2. nicht entspricht, wird nicht eingetreten.
# Sentence 216: Mit der Beschwerde können gerügt werden:
# Sentence 217: Rechtsverletzungen, einschliesslich Überschreitung oder Missbrauch des Ermessens
# Sentence 218: unrichtige oder unvollständige Feststellung des rechtserheblichen Sachverhalts.
# Sentence 219: Die angefochtene Ausschreibung ist anzugeben, allfällige Beweismittel sind zu bezeichnen und soweit möglich beizulegen.
# Sentence 220: Die Eingabe ist zu unterzeichnen.
# Sentence 221: Das Beschwerdeverfahren ist mit einem Kostenrisiko verbunden, das heisst die unterliegende Partei hat in der Regel die Verfahrenskosten sowie gegebenenfalls die gegnerischen Anwaltskosten zu bezahlen.
# Sentence 222: 16 Vergütung Die Ausarbeitung der Offerte und alle damit verbundenen Arbeiten erfolgen durch den Anbieter unentgeltlich.
# Sentence 223: Vorbehalte
# Sentence 224: 1 Kein garantiertes Auftragsvolumen Die Vergabestelle garantiert kein Auftragsvolumen für die Fleischwaren-Lieferungen.
# Sentence 225: Die Anbietenden haben keinen Anspruch darauf, dass die der Ausschreibung zugrundeliegenden Auftragsvolumina (Kapitel 3.2) dem zu erbringenden Leistungsumfang entsprechen.
# Sentence 226: Die genannten Mengen basieren auf realistischen Annahmen und Schätzungen.
# Sentence 227: 2 Angebote erfüllen Erwartungen nicht Sofern keines der eingereichten Angebote die in der Ausschreibung oder den Ausschreibungsunterlagen festgelegten Kriterien erfüllt oder keine wirtschaftliche Beschaffung erlauben, wird eine Neubeurteilung der gesamten Ausschreibung oder Teilen davon vorgenommen und eine neue, allenfalls veränderte Ausschreibung geprüft (vgl.
# Sentence 228: Art. 43 IVöB).
# Sentence 229: 3 Vertragsabschluss Der Vertragsabschluss erfolgt erst, wenn der Zuschlag erfolgt ist.
# Sentence 230: Der Zuschlag gibt jedoch keinen Anspruch auf den Abschluss eines Vertrages (keine Kontrahierungspflicht).
# Sentence 231: Evaluationsphase Unter dieser Ziffer wird nachfolgend einerseits der generelle Ablauf der Evaluationsphase erläutert, andererseits werden die einzelnen Schritte dieser Phase näher beschrieben.
# Sentence 232: 1 Projektorganisation Evaluation Die Evaluation erfolgt durch Mitarbeitende des Amts für Justizvollzug und weitere Mitarbeitende des Kantons Aargau.
# Sentence 233: Die in das Evaluationsverfahren einbezogenen Personen werden eine Unbefangenheitserklärung unterzeichnet haben. 14 von 18
# Sentence 234: 2 Ablauf Die Evaluationsphase beginnt mit der Offertöffnung und endet mit der Erteilung des Zuschlags oder dem Verfahrensabbruch.
# Sentence 235: Nach der Offertöffnung erfolgt in einem ersten Schritt die Ausschlussprüfung.
# Sentence 236: Dabei prüft die Vergabestelle, ob Anbietende aus insbesondere formalen Gründen (zum Beispiel fehlende Unterschrift, unvollständiges Angebot) oder wegen Nichterfüllung der Eignungskriterien unter Ziff. 7.4.2 vom Verfahren auszuschliessen sind.
# Sentence 237: Der Ausschluss wird den betreffenden Anbietenden mittels anfechtbarer Verfügung nach Durchführung der Ausschlussprüfung mitgeteilt.
# Sentence 238: In einem zweiten Schritt (Detailprüfung) prüft die Vergabestelle die eingegangenen Offerten in Bezug auf die Zuschlagskriterien anhand des unter Ziff. 7.4.3 dargelegten Bewertungsschemas.
# Sentence 239: Dadurch wird das wirtschaftlich günstigste und qualitativ beste Angebot ermittelt.
# Sentence 240: 3 Offertöffnung Die Offertöffnung erfolgt durch mindestens zwei Vertreter des Amts für Justizvollzug und ist nicht öffentlich.
#
# Annotations for 4_Harmonisiert_pflichtenheft:
# {'text': ['Alle Kinder erhalten eine ausgewogene, abwechslungsreiche, altersgemässe und warme Mahlzeit.', 'Alle Kinder erhalten eine ausgewogene, abwechslungsreiche, altersgemässe und warme Mahlzeit.', 'Altersgerechtes Angebot für Kinder im Alter von ein bis zwölf Jahren mit attrakti-\nven Menüs', 'Altersgerechtes Angebot für Kinder im Alter von ein bis zwölf Jahren mit attrakti-\nven Menüs', 'Bericht einer Ernährungsfachperson bezüglich Nährwert und Menüplanung (maximal \n\neine A4-Seite)', 'Vegetarische Komponenten', 'Regionale und saisonale Produkte', 'Regionale und saisonale Produkte', 'Minimierung von Foodwaste', 'Nachhaltige Verpackung / Gebinde', 'Allergiker- Report im Webshop', 'Umweltgerechte Fahrzeuge mit tie-\nfem Treibstoffverbrauch sind im Einsatz.'], 'criterion_id': ['food-K-047', 'food-K-046', 'food-K-046', 'food-K-047', 'food-K-049', 'food-HF-011', 'food-K-041', 'food-K-038', 'food-HF-013', 'food-K-045', 'food-K-051', 'food-K-072'], 'criterion_type': ['cc-undefined', 'cc-undefined', 'cc-award_criterion', 'cc-award_criterion', 'cc-award_criterion', 'cc-award_criterion', 'cc-award_criterion', 'cc-award_criterion', 'cc-award_criterion', 'cc-award_criterion', 'cc-award_criterion', 'cc-undefined']}
#
# Annotations for 2_Harmonisiert_pflichtenheft:
# {'text': ['Die massgeblichen Anforderungen sind in Form von Angaben zum Unternehmen, zu den verlangten \n\nEignungskriterien samt Bestätigungen, Referenzen und Darstellung der Einhaltung der \n\nSchweizerischen Tierschutzstandards sowie der Prinzipien der ökologischen Nachhaltigkeit bei \n\nProduktion und Transport (Beilage 1) und im Eingabeformular Preis (Beilage 2) aufgeführt.', 'Nachhaltigkeit', 'Der Anbieter verpflichten sich, die Standards gemäss Kernabkommen der ILO (International Labour \n\nOrganization), die geltenden Arbeitsschutzbestimmungen sowie die Bedingungen der \n\nGesamtarbeitsverträge, der Normalarbeitsverträge oder bei deren Fehlen die branchenüblichen \n\nVorschriften einzuhalten, die an den Orten gelten, wo die Arbeiten ausgeführt werden.', 'Der Anbieter verpflichten sich, die Standards gemäss Kernabkommen der ILO (International Labour \n\nOrganization), die geltenden Arbeitsschutzbestimmungen sowie die Bedingungen der \n\nGesamtarbeitsverträge, der Normalarbeitsverträge oder bei deren Fehlen die branchenüblichen \n\nVorschriften einzuhalten, die an den Orten gelten, wo die Arbeiten ausgeführt werden.', 'C Nachhaltigkeit   \n \n\nC.1 Beurteilung / Zertifikat 50 Punkte    \n         \n\n  Total Nachhaltigkeit  50 Punkte 5%'], 'criterion_id': ['food-K-053', 'food-K-053', 'food-K-030', 'food-K-078', 'food-K-053'], 'criterion_type': ['cc-selection_criteria', 'cc-award_criterion', 'cc-participation_conditions', 'cc-participation_conditions', None]}
#
# Annotations for 1_Harmonisiert_pflichtenheft:
# {'text': ['Sie verwenden Öle, Gewürze, Streusalze, Zucker, Backwaren, wie auch weitere Basisprodukte \nund Nahrungsmittel für die Zwischenmahlzeiten zu 50% (an Kosten gemessen) in der Qualität \n«Bio» und (bei Produkten aus der 3. Welt) mit dem Gütesiegel «Max Havelaar».', 'Sie verwenden Milch und Milchprodukte zu 90% (gemessen an den Kosten) aus Schweizer \nProduktion in der Qualität «Bio».', 'Sie verwenden Milch und Milchprodukte zu 90% (gemessen an den Kosten) aus Schweizer \nProduktion in der Qualität «Bio».', 'Sie verwenden Milch und Milchprodukte zu 90% (gemessen an den Kosten) aus Schweizer \nProduktion in der Qualität «Bio».', 'Sie produzieren Sättigungsbeilagen zu 80% (in 8 von 10 Mahlzeiten) in der Qualität «Bio» und \nverwenden (bei Produkten aus der 3 Welt) Produkte mit dem Gütesiegel «Max Havelaar». \nKartoffeln verwenden Sie ausschliesslich in der Qualität «Bio Suisse» aus der Region (35km \nvon Biel).', 'Kartoffeln verwenden Sie ausschliesslich in der Qualität «Bio Suisse» aus der Region (35km \nvon Biel).', 'Früchte verarbeiten und liefern Sie zu 80% (gemessen an den Kosten) in Qualität «Bio Suis-\nse» (Siehe Ausnahmen unter g).', 'Früchte verarbeiten und liefern Sie zu 80% (gemessen an den Kosten) in Qualität «Bio Suis-\nse» (Siehe Ausnahmen unter g).', 'Fruchtsäfte verarbeiten und liefern Sie zu 80% (gemessen an den Kosten) in der Qualität \n«Bio»', 'Sie liefern und verarbeiten zu 80% Früchte (gemessen an den Kosten) aus der Region (35km \nvon Biel).', 'Ausnahmen: Bananen, Mandarinen, Clementinen, Orangen: Diese sollen zu 70% (Gemessen \nan den Kosten) aus fairem Handel (Label Max Havelaar oder vergleichbar) und wenn möglich \naus biologischer Produktion stammen.', 'Sie verwenden zu 70% Gemüse (gemessen an den Kosten) in der Qualität «Bio Suisse».', 'Sie verwenden zu 70% Gemüse (gemessen an den Kosten) in der Qualität «Bio Suisse».', 'Sie verwenden zu 70% Gemüse (gemessen an den Kosten) aus der Region (35km von Biel).', 'Sie verwenden Salat ausschliesslich in der Qualität «Bio Suisse».', 'Sie verwenden zu 70% Salat (gemessen an den Kosten) aus der Region (35km von Biel).', 'Fleisch/Geflügel in der Qualität «IP» oder «Bio Suisse» aus der Region (35km von \nBiel)', 'Fleisch/Geflügel in der Qualität «IP» oder «Bio Suisse» aus der Region (35km von \nBiel)', 'Fleisch/Geflügel in der Qualität «IP» oder «Bio Suisse» aus der Region (35km von \nBiel)', 'Fleisch/Geflügel in der Qualität «IP» oder «Bio Suisse» aus der Region (35km von \nBiel)', 'Fleisch/Geflügel in der Qualität «IP» oder «Bio Suisse» aus der Region (35km von \nBiel)', 'Fleisch/Geflügel in der Qualität «IP» oder «Bio Suisse» aus der Region (35km von \nBiel)', 'Fleisch/Geflügel in der Qualität «IP» oder «Bio Suisse» aus der Region (35km von \nBiel)', 'Fisch im Standard «MSC»', 'Fisch im Standard «MSC»', '3 Hauptmahlzeiten pro Woche vegetarisch', 'Für Kinder die vegetarisch oder kein Schweinefleisch essen wird jeden Tag eine Ei-\nweisskomponente auf vegetarischer Basis angeboten.', 'Ausgewogenheit und kindergerecht innerhalb der Menüs: Die Produktion folgt einer \nErnährungsphilosophie auf Basis einer aktuellen wissenschaftlicher Grundlage. \nGeben Sie Ihre Philosophie an'], 'criterion_id': ['food-K-019', 'food-K-019', 'food-K-027', 'food-K-041', 'food-K-019', 'food-K-041', 'food-K-041', 'food-K-019', 'food-K-019', 'food-K-041', 'food-K-024', 'food-K-019', 'food-K-041', 'food-K-041', 'food-K-019', 'food-K-041', 'food-K-029', 'food-K-025', 'food-K-019', 'food-K-041', 'food-K-022', 'food-K-028', 'food-K-026', 'food-K-023', 'food-K-036', 'food-K-005', 'food-K-002', 'food-K-047'], 'criterion_type': ['cc-selection_criteria', 'cc-technical_specification', 'cc-technical_specification', 'cc-selection_criteria', 'cc-selection_criteria', None, 'cc-technical_specification', 'cc-selection_criteria', 'cc-technical_specification', 'cc-selection_criteria', 'cc-selection_criteria', 'cc-selection_criteria', 'cc-technical_specification', 'cc-selection_criteria', 'cc-selecti ...
